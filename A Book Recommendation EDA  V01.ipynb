# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statistics as st
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Book DataSet

# %%
book= pd.read_csv('Books_re.csv')

# %%
book
# Out:
#               ISBN                                         Book-Title  \
# 0       0195153448                                Classical Mythology
# 1       0002005018                                       Clara Callan
# 2       0060973129                               Decision in Normandy
# 3       0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4       0393045218                             The Mummies of Urumchi
# ...            ...                                                ...
# 271355  0440400988                         There's a Bat in Bunk Five
# 271356  0525447644                            From One to One Hundred
# 271357  006008667X  Lily Dale : The True Story of the Town that Ta...
# 271358  0192126040                        Republic (World's Classics)
# 271359  0767409752  A Guided Tour of Rene Descartes' Meditations o...
#
#                  Book-Author Year-Of-Publication  \
# 0         Mark P. O. Morford                2002
# ...

# %% [markdown]
# ### Information of data set

# %%
book.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 271360 entries, 0 to 271359
# Data columns (total 8 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   ISBN                 271360 non-null  object
#  1   Book-Title           271360 non-null  object
#  2   Book-Author          271359 non-null  object
#  3   Year-Of-Publication  271360 non-null  object
#  4   Publisher            271358 non-null  object
#  5   Image-URL-S          271360 non-null  object
#  6   Image-URL-M          271360 non-null  object
#  7   Image-URL-L          271357 non-null  object
# dtypes: object(8)
# memory usage: 16.6+ MB

# %% [markdown]
# ### Shape of Data set

# %%
book.shape
# Out:
# (271360, 8)

# %% [markdown]
# ### Type of data set

# %%
book.dtypes
# Out:
# ISBN                   object
# Book-Title             object
# Book-Author            object
# Year-Of-Publication    object
# Publisher              object
# Image-URL-S            object
# Image-URL-M            object
# Image-URL-L            object
# dtype: object

# %% [markdown]
# ### Null Values

# %%
book.isnull().sum()
# Out:
# ISBN                   0
# Book-Title             0
# Book-Author            1
# Year-Of-Publication    0
# Publisher              2
# Image-URL-S            0
# Image-URL-M            0
# Image-URL-L            3
# dtype: int64

# %%
book.describe().reset_index()
# Out:
#     index        ISBN      Book-Title      Book-Author  Year-Of-Publication  \
# 0   count      271360          271360           271359               271360
# 1  unique      271360          242135           102023                  202
# 2     top  0195153448  Selected Poems  Agatha Christie                 2002
# 3    freq           1              27              632                13903
#
#    Publisher                                        Image-URL-S  \
# 0     271358                                             271360
# 1      16807                                             271044
# 2  Harlequin  http://images.amazon.com/images/P/185326119X.0...
# 3       7535                                                  2
#
#                                          Image-URL-M  \
# 0                                             271360
# 1                                             271044
# 2  http://images.amazon.com/images/P/185326119X.0...
# ...

# %%
book.head()
# Out:
#          ISBN                                         Book-Title  \
# 0  0195153448                                Classical Mythology
# 1  0002005018                                       Clara Callan
# 2  0060973129                               Decision in Normandy
# 3  0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4  0393045218                             The Mummies of Urumchi
#
#             Book-Author Year-Of-Publication                   Publisher  \
# 0    Mark P. O. Morford                2002     Oxford University Press
# 1  Richard Bruce Wright                2001       HarperFlamingo Canada
# 2          Carlo D'Este                1991             HarperPerennial
# 3      Gina Bari Kolata                1999        Farrar Straus Giroux
# 4       E. J. W. Barber                1999  W. W. Norton &amp; Company
#
#                                          Image-URL-S  \
# 0  http://images.amazon.com/images/P/0195153448.0...
# ...

# %%
book.tail()
# Out:
#               ISBN                                         Book-Title  \
# 271355  0440400988                         There's a Bat in Bunk Five
# 271356  0525447644                            From One to One Hundred
# 271357  006008667X  Lily Dale : The True Story of the Town that Ta...
# 271358  0192126040                        Republic (World's Classics)
# 271359  0767409752  A Guided Tour of Rene Descartes' Meditations o...
#
#                 Book-Author Year-Of-Publication  \
# 271355       Paula Danziger                1988
# 271356           Teri Sloat                1991
# 271357     Christine Wicker                2004
# 271358                Plato                1996
# 271359  Christopher  Biffle                2000
#
#                                                Publisher  \
# 271355                   Random House Childrens Pub (Mm)
# 271356                                      Dutton Books
# 271357                                HarperSanFrancisco
# ...

# %%
#droping the Image columns which is not Required in EDA
book.drop(['Image-URL-S', 'Image-URL-L'],axis=1,inplace=True)

# %%
book.rename(columns = {'Book-Title':'title', 'Book-Author':'author', 'Year-Of-Publication':'year', 'Publisher':'publisher', 'Image-URL-M':'image-m'}, inplace=True)

# %%
book
# Out:
#               ISBN                                              title  \
# 0       0195153448                                Classical Mythology
# 1       0002005018                                       Clara Callan
# 2       0060973129                               Decision in Normandy
# 3       0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4       0393045218                             The Mummies of Urumchi
# ...            ...                                                ...
# 271355  0440400988                         There's a Bat in Bunk Five
# 271356  0525447644                            From One to One Hundred
# 271357  006008667X  Lily Dale : The True Story of the Town that Ta...
# 271358  0192126040                        Republic (World's Classics)
# 271359  0767409752  A Guided Tour of Rene Descartes' Meditations o...
#
#                       author  year  \
# 0         Mark P. O. Morford  2002
# 1       Richard Bruce Wright  2001
# ...

# %%
book_isbn = book.groupby('ISBN').count()['title'].reset_index()
book_isbn
# Out:
#               ISBN  title
# 0       0000913154      1
# 1       0001010565      1
# 2       0001046438      1
# 3       0001046713      1
# 4       000104687X      1
# ...            ...    ...
# 271355  B000234N76      1
# 271356  B000234NC6      1
# 271357  B00029DGGO      1
# 271358  B0002JV9PY      1
# 271359  B0002K6K8O      1
#
# [271360 rows x 2 columns]

# %%
book_bt = book.sort_values("title", inplace = True)
book_bt = book["title"].duplicated()
book_bt.value_counts()
# Out:
# False    242135
# True      29225
# Name: title, dtype: int64

# %%
book['year'].describe()
# Out:
# count     271360
# unique       202
# top         2002
# freq       13903
# Name: year, dtype: int64

# %%
book['year'].unique()
# Out:
# array([1999, '1994', 1984, 2001, 1989, '2000', 2004, 1994, 1991, 2002,
#        1996, '1995', 1995, '2001', '1998', '1997', 1997, '1973', '1999',
#        1998, 1990, 1987, '2003', 1979, 1993, 1986, 2000, '2002', 1992, 0,
#        1983, 1972, '1985', '1992', 1988, 1985, 2003, 1980, '1987', 1966,
#        1953, '1984', '1978', 1951, '1990', '1976', '1989', '1996', 1982,
#        '1991', '1993', '1982', '1971', 1973, '1974', 1981, '0', '1965',
#        1959, 1976, 1977, 1971, 1978, '1986', '1988', '2004', '1980',
#        '1983', '1977', '1979', '1975', 1975, '1963', 1968, 1963, '1969',
#        1969, '1981', '1968', '1964', 1974, 1955, '1957', 1970, '1972',
#        '1952', 1962, 1965, 1961, '1958', 1911, '1962', '1970', 1967, 1935,
#        '1954', 1939, 1964, '1959', 2011, '1967', '1947', 1960, 2005, 1958,
#        1956, '1944', '1955', '1950', '1960', '1961', 1920, 1957, '1946',
#        1946, 2050, 1929, 1936, '1966', 1945, '2008', 1954, '1956', 1940,
# ...

# %%
book.loc[book['year'] == 'DK Publishing Inc',:]
# Out:
#               ISBN                                              title author  \
# 221678  0789466953  DK Readers: Creating the X-Men, How Comic Book...   2000
# 209538  078946697X  DK Readers: Creating the X-Men, How It All Beg...   2000
#
#                      year                                          publisher  \
# 221678  DK Publishing Inc  http://images.amazon.com/images/P/0789466953.0...
# 209538  DK Publishing Inc  http://images.amazon.com/images/P/078946697X.0...
#
#                                                   image-m
# 221678  http://images.amazon.com/images/P/0789466953.0...
# 209538  http://images.amazon.com/images/P/078946697X.0...

# %%
book.loc[book.ISBN == '0789466953','year'] = 2000
book.loc[book.ISBN == '0789466953','author'] = "James Buckley"
book.loc[book.ISBN == '0789466953','publisher'] = "DK Publishing Inc"
book.loc[book.ISBN == '0789466953','title'] = "DK Readers: Creating the X-Men, How Comic Books Come to Life (Level 4: Proficient Readers)"

# %%
book.loc[book.ISBN == '078946697X','year'] = 2000
book.loc[book.ISBN == '078946697X','author'] = "Michael Teitelbaum"
book.loc[book.ISBN == '078946697X','publisher'] = "DK Publishing Inc"
book.loc[book.ISBN == '078946697X','title'] = "DK Readers: Creating the X-Men, How It All Began (Level 4: Proficient Readers)"

# %%
book.loc[(book.ISBN == '0789466953') | (book.ISBN == '078946697X'),:]
# Out:
#               ISBN                                              title  \
# 221678  0789466953  DK Readers: Creating the X-Men, How Comic Book...
# 209538  078946697X  DK Readers: Creating the X-Men, How It All Beg...
#
#                     author  year          publisher  \
# 221678       James Buckley  2000  DK Publishing Inc
# 209538  Michael Teitelbaum  2000  DK Publishing Inc
#
#                                                   image-m
# 221678  http://images.amazon.com/images/P/0789466953.0...
# 209538  http://images.amazon.com/images/P/078946697X.0...

# %%
book.loc[book['year'] == 'Gallimard',:]
# Out:
#               ISBN                                              title author  \
# 220731  2070426769  Peuple du ciel, suivi de 'Les Bergers\";Jean-M...   2003
#
#              year                                          publisher  \
# 220731  Gallimard  http://images.amazon.com/images/P/2070426769.0...
#
#                                                   image-m
# 220731  http://images.amazon.com/images/P/2070426769.0...

# %%
book.loc[book.ISBN == '2070426769','year'] = 2003
book.loc[book.ISBN == '2070426769','author'] = "Jean-Marie Gustave Le ClÃ?Â©zio"
book.loc[book.ISBN == '2070426769','publisher'] = "Gallimard"
book.loc[book.ISBN == '2070426769','title'] = "Peuple du ciel, suivi de 'Les Bergers"

# %%
book.loc[book.ISBN == '2070426769',:]
# Out:
#               ISBN                                  title  \
# 220731  2070426769  Peuple du ciel, suivi de 'Les Bergers
#
#                                  author  year  publisher  \
# 220731  Jean-Marie Gustave Le ClÃ?Â©zio  2003  Gallimard
#
#                                                   image-m
# 220731  http://images.amazon.com/images/P/2070426769.0...

# %%
book['year'].unique()
# Out:
# array([1999, '1994', 1984, 2001, 1989, '2000', 2004, 1994, 1991, 2002,
#        1996, '1995', 1995, '2001', '1998', '1997', 1997, '1973', '1999',
#        1998, 1990, 1987, '2003', 1979, 1993, 1986, 2000, '2002', 1992, 0,
#        1983, 1972, '1985', '1992', 1988, 1985, 2003, 1980, '1987', 1966,
#        1953, '1984', '1978', 1951, '1990', '1976', '1989', '1996', 1982,
#        '1991', '1993', '1982', '1971', 1973, '1974', 1981, '0', '1965',
#        1959, 1976, 1977, 1971, 1978, '1986', '1988', '2004', '1980',
#        '1983', '1977', '1979', '1975', 1975, '1963', 1968, 1963, '1969',
#        1969, '1981', '1968', '1964', 1974, 1955, '1957', 1970, '1972',
#        '1952', 1962, 1965, 1961, '1958', 1911, '1962', '1970', 1967, 1935,
#        '1954', 1939, 1964, '1959', 2011, '1967', '1947', 1960, 2005, 1958,
#        1956, '1944', '1955', '1950', '1960', '1961', 1920, 1957, '1946',
#        1946, 2050, 1929, 1936, '1966', 1945, '2008', 1954, '1956', 1940,
# ...

# %%
book['year'].describe()
# Out:
# count     271360
# unique       200
# top         2002
# freq       13903
# Name: year, dtype: int64

# %%
print(book.loc[book.year == '1376',:])
print(book.loc[book.year == '1378',:])
print(book.loc[book.year == '1806',:])
print(book.loc[book.year == '1897',:])
# Out:
#               ISBN         title          author  year       publisher  \
# 253750  964442011X  Tasht-i khun  IsmaÂ°il Fasih  1376  Nashr-i Alburz
#
#                                                   image-m
# 253750  http://images.amazon.com/images/P/964442011X.0...
#               ISBN                             title       author  year  \
# 227531  9643112136  Dalan-i bihisht (Dastan-i Irani)  Nazi Safavi  1378
#
#                   publisher                                            image-m
# 227531  Intisharat-i Quqnus  http://images.amazon.com/images/P/9643112136.0...
# Empty DataFrame
# Columns: [ISBN, title, author, year, publisher, image-m]
# Index: []
#               ISBN                                              title  \
# 245607  0781268001  Hugh Wynne, Free Quaker (2 Volumes (BCL1-PS Am...
#
#                      author  year              publisher  \
# 245607  Silas Weir Mitchell  1897  Reprint Services Corp
#
# ...

# %%
book.year=pd.to_numeric(book.year, errors='coerce')

# %%
book.loc[(book['year'] > 2022) | (book.year == 0),'year'] = np.NAN

# %%
book['year'].isna().sum()
# Out:
# 4631

# %%
book['year'].describe()
# Out:
# count    266729.000000
# mean       1993.687915
# std           8.321191
# min        1376.000000
# 25%        1989.000000
# 50%        1996.000000
# 75%        2000.000000
# max        2021.000000
# Name: year, dtype: float64

# %%
book.year.fillna(round(book.year.max()), inplace=True)

# %%
book.year.isnull().sum()
# Out:
# 0

# %%
print(sorted(book['year'].unique()))
# Out:
# [1376.0, 1378.0, 1806.0, 1897.0, 1900.0, 1901.0, 1902.0, 1904.0, 1906.0, 1908.0, 1909.0, 1910.0, 1911.0, 1914.0, 1917.0, 1919.0, 1920.0, 1921.0, 1922.0, 1923.0, 1924.0, 1925.0, 1926.0, 1927.0, 1928.0, 1929.0, 1930.0, 1931.0, 1932.0, 1933.0, 1934.0, 1935.0, 1936.0, 1937.0, 1938.0, 1939.0, 1940.0, 1941.0, 1942.0, 1943.0, 1944.0, 1945.0, 1946.0, 1947.0, 1948.0, 1949.0, 1950.0, 1951.0, 1952.0, 1953.0, 1954.0, 1955.0, 1956.0, 1957.0, 1958.0, 1959.0, 1960.0, 1961.0, 1962.0, 1963.0, 1964.0, 1965.0, 1966.0, 1967.0, 1968.0, 1969.0, 1970.0, 1971.0, 1972.0, 1973.0, 1974.0, 1975.0, 1976.0, 1977.0, 1978.0, 1979.0, 1980.0, 1981.0, 1982.0, 1983.0, 1984.0, 1985.0, 1986.0, 1987.0, 1988.0, 1989.0, 1990.0, 1991.0, 1992.0, 1993.0, 1994.0, 1995.0, 1996.0, 1997.0, 1998.0, 1999.0, 2000.0, 2001.0, 2002.0, 2003.0, 2004.0, 2005.0, 2006.0, 2008.0, 2010.0, 2011.0, 2012.0, 2020.0, 2021.0]

# %%
sns.boxplot(book['year'])
# Out:
# <AxesSubplot:>

# %%
book.loc[book.ISBN == '964442011X',:]
# Out:
#               ISBN         title          author    year       publisher  \
# 253750  964442011X  Tasht-i khun  IsmaÂ°il Fasih  1376.0  Nashr-i Alburz
#
#                                                   image-m
# 253750  http://images.amazon.com/images/P/964442011X.0...

# %%
book.loc[book.ISBN == '9643112136',:]
# Out:
#               ISBN                             title       author    year  \
# 227531  9643112136  Dalan-i bihisht (Dastan-i Irani)  Nazi Safavi  1378.0
#
#                   publisher                                            image-m
# 227531  Intisharat-i Quqnus  http://images.amazon.com/images/P/9643112136.0...

# %%
book.loc[book.ISBN == '0781268001',:]
# Out:
#               ISBN                                              title  \
# 245607  0781268001  Hugh Wynne, Free Quaker (2 Volumes (BCL1-PS Am...
#
#                      author    year              publisher  \
# 245607  Silas Weir Mitchell  1897.0  Reprint Services Corp
#
#                                                   image-m
# 245607  http://images.amazon.com/images/P/0781268001.0...

# %%
book.loc[(book['year'] < 1897) | (book.year == 0),'year'] = np.NAN
book = book.dropna(subset=['year'])
book.year.isnull().sum()
# Out:
# 0

# %%
print(sorted(book['year'].unique()))
# Out:
# [1897.0, 1900.0, 1901.0, 1902.0, 1904.0, 1906.0, 1908.0, 1909.0, 1910.0, 1911.0, 1914.0, 1917.0, 1919.0, 1920.0, 1921.0, 1922.0, 1923.0, 1924.0, 1925.0, 1926.0, 1927.0, 1928.0, 1929.0, 1930.0, 1931.0, 1932.0, 1933.0, 1934.0, 1935.0, 1936.0, 1937.0, 1938.0, 1939.0, 1940.0, 1941.0, 1942.0, 1943.0, 1944.0, 1945.0, 1946.0, 1947.0, 1948.0, 1949.0, 1950.0, 1951.0, 1952.0, 1953.0, 1954.0, 1955.0, 1956.0, 1957.0, 1958.0, 1959.0, 1960.0, 1961.0, 1962.0, 1963.0, 1964.0, 1965.0, 1966.0, 1967.0, 1968.0, 1969.0, 1970.0, 1971.0, 1972.0, 1973.0, 1974.0, 1975.0, 1976.0, 1977.0, 1978.0, 1979.0, 1980.0, 1981.0, 1982.0, 1983.0, 1984.0, 1985.0, 1986.0, 1987.0, 1988.0, 1989.0, 1990.0, 1991.0, 1992.0, 1993.0, 1994.0, 1995.0, 1996.0, 1997.0, 1998.0, 1999.0, 2000.0, 2001.0, 2002.0, 2003.0, 2004.0, 2005.0, 2006.0, 2008.0, 2010.0, 2011.0, 2012.0, 2020.0, 2021.0]

# %%
book.loc[book.publisher.isnull(),:]
# Out:
#               ISBN            title           author    year publisher  \
# 129037  1931696993  Finders Keepers  Linnea Sinclair  2001.0       NaN
# 128890  193169656X      Tyrant Moon  Elaine Corvidae  2002.0       NaN
#
#                                                   image-m
# 129037  http://images.amazon.com/images/P/1931696993.0...
# 128890  http://images.amazon.com/images/P/193169656X.0...

# %%
book.loc[(book.title == 'Tyrant Moon'),:]
# Out:
#               ISBN        title           author    year publisher  \
# 128890  193169656X  Tyrant Moon  Elaine Corvidae  2002.0       NaN
#
#                                                   image-m
# 128890  http://images.amazon.com/images/P/193169656X.0...

# %%
book.loc[(book.title == 'Finders Keepers'),:]
# Out:
#               ISBN            title            author    year  \
# 58264   0688118461  Finders Keepers       Emily Rodda  1993.0
# 134309  0156309505  Finders Keepers              Will  1989.0
# 173473  0973146907  Finders Keepers  Sean M. Costello  2002.0
# 10799   082177364X  Finders Keepers     Fern Michaels  2002.0
# 129037  1931696993  Finders Keepers   Linnea Sinclair  2001.0
# 211874  0373261160  Finders Keepers  Elizabeth Travis  1993.0
# 66678   1575663236  Finders Keepers     Fern Michaels  1998.0
# 195885  0061083909  Finders Keepers       Sharon Sala  2003.0
# 42019   0070465037  Finders Keepers  Barbara Nickolae  1989.0
#
#                                 publisher  \
# 58264        Harpercollins Juvenile Books
# 134309                      Voyager Books
# 173473             Red Tower Publications
# 10799                         Zebra Books
# 129037                                NaN
# 211874                  Worldwide Library
# 66678   Kensington Publishing Corporation
# ...

# %%
book.loc[(book.author == 'Elaine Corvidae'),:]
# Out:
#               ISBN             title           author    year  \
# 128890  193169656X       Tyrant Moon  Elaine Corvidae  2002.0
# 126762  1931696934  Winter's Orphans  Elaine Corvidae  2001.0
# 129001  0759901880           Wolfkin  Elaine Corvidae  2001.0
#
#                       publisher  \
# 128890                      NaN
# 126762               Novelbooks
# 129001  Hard Shell Word Factory
#
#                                                   image-m
# 128890  http://images.amazon.com/images/P/193169656X.0...
# 126762  http://images.amazon.com/images/P/1931696934.0...
# 129001  http://images.amazon.com/images/P/0759901880.0...

# %%
book.loc[(book.author == 'Linnea Sinclair'),:]
# Out:
#               ISBN            title           author    year publisher  \
# 129037  1931696993  Finders Keepers  Linnea Sinclair  2001.0       NaN
#
#                                                   image-m
# 129037  http://images.amazon.com/images/P/1931696993.0...

# %%
book.loc[(book.ISBN == '193169656X'),'publisher'] = 'other'
book.loc[(book.ISBN == '1931696993'),'publisher'] = 'other'

# %%
#book = book.dropna(subset=['publisher'])
#book.publisher.isnull().sum()

# %%
book.loc[book.author.isnull(),:]
# Out:
#               ISBN                                              title author  \
# 187689  9627982032  The Credit Suisse Guide to Managing Your Perso...    NaN
#
#           year                       publisher  \
# 187689  1995.0  Edinburgh Financial Publishing
#
#                                                   image-m
# 187689  http://images.amazon.com/images/P/9627982032.0...

# %%
book.loc[(book.publisher == 'Edinburgh Financial Publishing'),:]
# Out:
#               ISBN                                              title author  \
# 187689  9627982032  The Credit Suisse Guide to Managing Your Perso...    NaN
#
#           year                       publisher  \
# 187689  1995.0  Edinburgh Financial Publishing
#
#                                                   image-m
# 187689  http://images.amazon.com/images/P/9627982032.0...

# %%
book = book.dropna(subset=['author'])
book.author.isnull().sum()
# Out:
# 0

# %%
book.isnull().sum()
# Out:
# ISBN         0
# title        0
# author       0
# year         0
# publisher    0
# image-m      0
# dtype: int64

# %% [markdown]
# ## Users Dataset

# %%
user=pd.read_csv('Users_re.csv')

# %%
user
# Out:
#         User-ID                            Location   Age
# 0             1                  nyc, new york, usa   NaN
# 1             2           stockton, california, usa  18.0
# 2             3     moscow, yukon territory, russia   NaN
# 3             4           porto, v.n.gaia, portugal  17.0
# 4             5  farnborough, hants, united kingdom   NaN
# ...         ...                                 ...   ...
# 278853   278854               portland, oregon, usa   NaN
# 278854   278855  tacoma, washington, united kingdom  50.0
# 278855   278856           brampton, ontario, canada   NaN
# 278856   278857           knoxville, tennessee, usa   NaN
# 278857   278858                dublin, n/a, ireland   NaN
#
# [278858 rows x 3 columns]

# %%
user.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 278858 entries, 0 to 278857
# Data columns (total 3 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   User-ID   278858 non-null  int64
#  1   Location  278858 non-null  object
#  2   Age       168096 non-null  float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 6.4+ MB

# %%
user.shape
# Out:
# (278858, 3)

# %%
user.dtypes
# Out:
# User-ID       int64
# Location     object
# Age         float64
# dtype: object

# %%
user.isnull().sum()
# Out:
# User-ID          0
# Location         0
# Age         110762
# dtype: int64

# %%
user.describe()
# Out:
#             User-ID            Age
# count  278858.00000  168096.000000
# mean   139429.50000      34.751434
# std     80499.51502      14.428097
# min         1.00000       0.000000
# 25%     69715.25000      24.000000
# 50%    139429.50000      32.000000
# 75%    209143.75000      44.000000
# max    278858.00000     244.000000

# %%
user.rename(columns = {'User-ID':'userid', 'Location':'location', 'Age':'age'}, inplace=True)

# %%
user_ui = user.sort_values("userid")
user_ui = user["userid"].duplicated()
user_ui.value_counts()
# Out:
# False    278858
# Name: userid, dtype: int64

# %%
user['location'] = user['location'].apply(lambda row: str(row).split(',')[-1])
user['location'].value_counts().to_frame().head(10)
# Out:
#                  location
#  usa               139711
#  canada             21658
#  united kingdom     18538
#  germany            17043
#  spain              13147
#  australia          11784
#  italy              11266
#                      4578
#  france              3455
#  portugal            3325

# %%
user
# Out:
#         userid         location   age
# 0            1              usa   NaN
# 1            2              usa  18.0
# 2            3           russia   NaN
# 3            4         portugal  17.0
# 4            5   united kingdom   NaN
# ...        ...              ...   ...
# 278853  278854              usa   NaN
# 278854  278855   united kingdom  50.0
# 278855  278856           canada   NaN
# 278856  278857              usa   NaN
# 278857  278858          ireland   NaN
#
# [278858 rows x 3 columns]

# %%
user['location'].unique()
# Out:
# array([' usa', ' russia', ' portugal', ' united kingdom', ' canada',
#        ' spain', ' australia', ' brazil', '', ' germany', ' mexico',
#        ' china', ' italy', ' distrito federal', ' france', ' netherlands',
#        ' iraq', ' finland', ' new zealand', ' india', ' ghana',
#        ' switzerland', ' slovenia', ' iran', ' peru',
#        ' bosnia and herzegovina', ' vietnam', ' sri lanka', ' pakistan',
#        ' denmark', ' belgium', ' malaysia', ' u.a.e', ' turkey',
#        ' philippines', ' greece', ' colombia', ' norway', ' kuwait',
#        ' chile', ' quit', ' lj', ' taiwan', ' denmark"', ' españa',
#        ' sweden', ' argentina', ' nigeria', ' london', ' bulgaria',
#        ' austria', ' romania', ' singapore', ' albania', ' egypt',
#        ' tunisia', ' uzbekistan', ' qatar', ' syria', ' saudi arabia',
#        ' indonesia', ' sudan', ' somewherein space', ' poland',
#        ' thailand', ' ireland', ' malaysia"', ' venezuela', ' paraguay',
# ...

# %%
user['location'].replace(['','01776','02458','19104','23232','30064','85021','87510','alachua','america','austria','autralia','cananda','geermany','italia','united kindgonm','united sates','united staes','united state','united states','us'],
                           ['other','usa','usa','usa','usa','usa','usa','usa','usa','usa','australia','australia','canada','germany','italy','united kingdom','usa','usa','usa','usa','usa'],inplace=True)

# %%
user['age'].unique()
# Out:
# array([ nan,  18.,  17.,  61.,  26.,  14.,  25.,  19.,  46.,  55.,  32.,
#         24.,  20.,  34.,  23.,  51.,  31.,  21.,  44.,  30.,  57.,  43.,
#         37.,  41.,  54.,  42.,  50.,  39.,  53.,  47.,  36.,  28.,  35.,
#         13.,  58.,  49.,  38.,  45.,  62.,  63.,  27.,  33.,  29.,  66.,
#         40.,  15.,  60.,   0.,  79.,  22.,  16.,  65.,  59.,  48.,  72.,
#         56.,  67.,   1.,  80.,  52.,  69.,  71.,  73.,  78.,   9.,  64.,
#        103., 104.,  12.,  74.,  75., 231.,   3.,  76.,  83.,  68., 119.,
#         11.,  77.,   2.,  70.,  93.,   8.,   7.,   4.,  81., 114., 230.,
#        239.,  10.,   5., 148., 151.,   6., 101., 201.,  96.,  84.,  82.,
#         90., 123., 244., 133.,  91., 128.,  94.,  85., 141., 110.,  97.,
#        219.,  86., 124.,  92., 175., 172., 209., 212., 237.,  87., 162.,
#        100., 156., 136.,  95.,  89., 106.,  99., 108., 210.,  88., 199.,
#        147., 168., 132., 159., 186., 152., 102., 116., 200., 115., 226.,
# ...

# %%
user['age'].describe()
# Out:
# count    168096.000000
# mean         34.751434
# std          14.428097
# min           0.000000
# 25%          24.000000
# 50%          32.000000
# 75%          44.000000
# max         244.000000
# Name: age, dtype: float64

# %%
user.loc[(user.age > 85) | (user.age < 10), 'age'] = np.nan

# %%
plt.figure(figsize=(10, 7))
user.age.hist(bins=40, color='teal')
# Out:
# <AxesSubplot:>

# %%
user.age = user.age.fillna(user.age.mean())

# %%
user.age = user.age.astype(np.int32)

# %%
user['age'].isnull().sum()
# Out:
# 0

# %%
user
# Out:
#         userid         location  age
# 0            1              usa   34
# 1            2              usa   18
# 2            3           russia   34
# 3            4         portugal   17
# 4            5   united kingdom   34
# ...        ...              ...  ...
# 278853  278854              usa   34
# 278854  278855   united kingdom   50
# 278855  278856           canada   34
# 278856  278857              usa   34
# 278857  278858          ireland   34
#
# [278858 rows x 3 columns]

# %% [markdown]
# ## Rating Dataset

# %%
rating=pd.read_csv('Ratings_re.csv')

# %%
rating
# Out:
#          User-ID         ISBN  Book-Rating
# 0         276725   034545104X            0
# 1         276726   0155061224            5
# 2         276727   0446520802            0
# 3         276729   052165615X            3
# 4         276729   0521795028            6
# ...          ...          ...          ...
# 1149775   276704   1563526298            9
# 1149776   276706   0679447156            0
# 1149777   276709   0515107662           10
# 1149778   276721   0590442449           10
# 1149779   276723  05162443314            8
#
# [1149780 rows x 3 columns]

# %%
rating.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1149780 entries, 0 to 1149779
# Data columns (total 3 columns):
#  #   Column       Non-Null Count    Dtype
# ---  ------       --------------    -----
#  0   User-ID      1149780 non-null  int64
#  1   ISBN         1149780 non-null  object
#  2   Book-Rating  1149780 non-null  int64
# dtypes: int64(2), object(1)
# memory usage: 26.3+ MB

# %%
rating.shape
# Out:
# (1149780, 3)

# %%
rating.dtypes
# Out:
# User-ID         int64
# ISBN           object
# Book-Rating     int64
# dtype: object

# %%
rating.isnull().sum()
# Out:
# User-ID        0
# ISBN           0
# Book-Rating    0
# dtype: int64

# %%
rating.describe()
# Out:
#             User-ID   Book-Rating
# count  1.149780e+06  1.149780e+06
# mean   1.403864e+05  2.866950e+00
# std    8.056228e+04  3.854184e+00
# min    2.000000e+00  0.000000e+00
# 25%    7.034500e+04  0.000000e+00
# 50%    1.410100e+05  0.000000e+00
# 75%    2.110280e+05  7.000000e+00
# max    2.788540e+05  1.000000e+01

# %%
rating.rename(columns = {'User-ID':'userid', 'Book-Rating':'bookrating'}, inplace=True)

# %%
rating
# Out:
#          userid         ISBN  bookrating
# 0        276725   034545104X           0
# 1        276726   0155061224           5
# 2        276727   0446520802           0
# 3        276729   052165615X           3
# 4        276729   0521795028           6
# ...         ...          ...         ...
# 1149775  276704   1563526298           9
# 1149776  276706   0679447156           0
# 1149777  276709   0515107662          10
# 1149778  276721   0590442449          10
# 1149779  276723  05162443314           8
#
# [1149780 rows x 3 columns]

# %%
rating['bookrating'].describe()
# Out:
# count    1.149780e+06
# mean     2.866950e+00
# std      3.854184e+00
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      7.000000e+00
# max      1.000000e+01
# Name: bookrating, dtype: float64

# %%
rating['bookrating'].unique()
# Out:
# array([ 0,  5,  3,  6,  8,  7, 10,  9,  4,  1,  2], dtype=int64)

# %%
rating_count = rating['bookrating'].value_counts()
rating_count
# Out:
# 0     716109
# 8     103736
# 10     78610
# 7      76457
# 9      67541
# 5      50974
# 6      36924
# 4       8904
# 3       5996
# 2       2759
# 1       1770
# Name: bookrating, dtype: int64

# %%
x = rating['ISBN'].value_counts()>50
x[x]
# Out:
# 0971880107    True
# 0316666343    True
# 0385504209    True
# 0060928336    True
# 0312195516    True
#               ...
# 0312979886    True
# 0451208811    True
# 0553280147    True
# 0440110653    True
# 0399133143    True
# Name: ISBN, Length: 2125, dtype: bool

# %%
def lst(x):
    if all(itm == 0 for itm in x):
        return x
    else:
        lt = [i for i in x if i != 0]
        return lt

# %%
rat = rating.drop('userid', axis=1)
rate = pd.DataFrame(rat.groupby('ISBN')['bookrating'].apply(list)).reset_index()
rate['bookrating1'] = rate['bookrating'].apply(lambda x: lst(x))
rate
# Out:
#                ISBN bookrating bookrating1
# 0        0330299891     [0, 6]         [6]
# 1        0375404120     [3, 0]         [3]
# 2        0586045007        [0]         [0]
# 3        9022906116     [7, 0]         [7]
# 4        9032803328        [0]         [0]
# ...             ...        ...         ...
# 340551     cn113107        [0]         [0]
# 340552   ooo7156103        [7]         [7]
# 340553   §423350229        [0]         [0]
# 340554  ´3499128624        [8]         [8]
# 340555    Ô½crosoft        [7]         [7]
#
# [340556 rows x 3 columns]

# %%
rate['counts'] = rate['bookrating'].apply(len)
rate['counts_no_zero'] = rate['bookrating1'].apply(len)
rate
# Out:
#                ISBN bookrating bookrating1  counts  counts_no_zero
# 0        0330299891     [0, 6]         [6]       2               1
# 1        0375404120     [3, 0]         [3]       2               1
# 2        0586045007        [0]         [0]       1               1
# 3        9022906116     [7, 0]         [7]       2               1
# 4        9032803328        [0]         [0]       1               1
# ...             ...        ...         ...     ...             ...
# 340551     cn113107        [0]         [0]       1               1
# 340552   ooo7156103        [7]         [7]       1               1
# 340553   §423350229        [0]         [0]       1               1
# 340554  ´3499128624        [8]         [8]       1               1
# 340555    Ô½crosoft        [7]         [7]       1               1
#
# [340556 rows x 5 columns]

# %%
rate['avg_rating'] = rate['bookrating'].apply(st.mean)
rate['avg_rating_no_zero'] = rate['bookrating1'].apply(st.mean)
rate['final_rating'] = round((rate['avg_rating']+rate['avg_rating_no_zero'])/2 , 3)
rate = rate.sort_values('counts', ascending=False).reset_index()
rate
# Out:
#          index        ISBN                                         bookrating  \
# 0       247408  0971880107  [0, 0, 0, 2, 0, 0, 0, 0, 0, 0, 0, 9, 0, 0, 0, ...
# 1        47371  0316666343  [0, 0, 0, 0, 7, 7, 0, 9, 0, 0, 10, 3, 7, 0, 10...
# 2        83359  0385504209  [8, 8, 0, 0, 10, 10, 7, 9, 7, 9, 10, 0, 10, 10...
# 3         9637  0060928336  [0, 0, 0, 7, 9, 5, 9, 7, 0, 6, 6, 0, 0, 0, 8, ...
# 4        41007  0312195516  [7, 10, 0, 0, 9, 0, 0, 0, 9, 9, 9, 0, 0, 0, 0,...
# ...        ...         ...                                                ...
# 340551  200161  0801064090                                                [0]
# 340552  200162  0801064252                                                [5]
# 340553  200163  0801064279                                                [0]
# 340554  200164  0801064333                                                [0]
# 340555  340555   Ô½crosoft                                                [7]
#
# ...

# %%
rate
# Out:
#          index        ISBN                                         bookrating  \
# 0       247408  0971880107  [0, 0, 0, 2, 0, 0, 0, 0, 0, 0, 0, 9, 0, 0, 0, ...
# 1        47371  0316666343  [0, 0, 0, 0, 7, 7, 0, 9, 0, 0, 10, 3, 7, 0, 10...
# 2        83359  0385504209  [8, 8, 0, 0, 10, 10, 7, 9, 7, 9, 10, 0, 10, 10...
# 3         9637  0060928336  [0, 0, 0, 7, 9, 5, 9, 7, 0, 6, 6, 0, 0, 0, 8, ...
# 4        41007  0312195516  [7, 10, 0, 0, 9, 0, 0, 0, 9, 9, 9, 0, 0, 0, 0,...
# ...        ...         ...                                                ...
# 340551  200161  0801064090                                                [0]
# 340552  200162  0801064252                                                [5]
# 340553  200163  0801064279                                                [0]
# 340554  200164  0801064333                                                [0]
# 340555  340555   Ô½crosoft                                                [7]
#
# ...

# %% [markdown]
# ## Merge Dataset of rate and rating on Basis of ISBN

# %%
rate_new=rate.merge(rating,on='ISBN')
rate_new = rate_new.drop('index', axis=1)
rate_new
# Out:
#                ISBN                                       bookrating_x  \
# 0        0971880107  [0, 0, 0, 2, 0, 0, 0, 0, 0, 0, 0, 9, 0, 0, 0, ...
# 1        0971880107  [0, 0, 0, 2, 0, 0, 0, 0, 0, 0, 0, 9, 0, 0, 0, ...
# 2        0971880107  [0, 0, 0, 2, 0, 0, 0, 0, 0, 0, 0, 9, 0, 0, 0, ...
# 3        0971880107  [0, 0, 0, 2, 0, 0, 0, 0, 0, 0, 0, 9, 0, 0, 0, ...
# 4        0971880107  [0, 0, 0, 2, 0, 0, 0, 0, 0, 0, 0, 9, 0, 0, 0, ...
# ...             ...                                                ...
# 1149775  0801064090                                                [0]
# 1149776  0801064252                                                [5]
# 1149777  0801064279                                                [0]
# 1149778  0801064333                                                [0]
# 1149779   Ô½crosoft                                                [7]
#
#                                                bookrating1  counts  \
# ...

# %%
rating_new=rate_new[['userid','ISBN','counts','counts_no_zero','final_rating']]
rating_new.sort_values('final_rating',ascending=False)
# Out:
#          userid        ISBN  counts  counts_no_zero  final_rating
# 1097109   76499  0571177387       1               1          10.0
# 1125484   30994  0764156314       1               1          10.0
# 964541    98391  1932815082       1               1          10.0
# 964540    98391  1932815066       1               1          10.0
# 1082544  200556  0471439150       1               1          10.0
# ...         ...         ...     ...             ...           ...
# 833257   145164  1559722304       3               3           0.0
# 995779    28373  006016848x       1               1           0.0
# 995780   261414  8475300340       1               1           0.0
# 833256    81771  1569870497       3               3           0.0
# 1033811  125224  3.44244314       1               1           0.0
#
# [1149780 rows x 5 columns]

# %% [markdown]
# ## Merge the Rating and User data on basis of User ID

# %%
rating_with_user=rating_new.merge(user,on='userid')
rating_with_user
# Out:
#          userid        ISBN  counts  counts_no_zero  final_rating  location  \
# 0        276925  0971880107    2502             581         2.705     spain
# 1        276925  0316666343    1295             707         6.327     spain
# 2        276925  0385504209     883             487         6.544     spain
# 3        276925  0804106304     519             194         5.630     spain
# 4        276925  002542730X     171              77         5.660     spain
# ...         ...         ...     ...             ...           ...       ...
# 1149775  109339  0801438543       1               1         7.000       usa
# 1149776  141040  0801491304       1               1         8.000   germany
# 1149777  263665  0801064562       1               1         0.000       usa
# 1149778  271450  0801064422       1               1        10.000       usa
# 1149779   54271  0801063248       1               1         0.000    canada
#
#          age
# 0         22
# 1         22
# ...

# %%
rating_with_user=rating_with_user[['userid','ISBN','location','age','counts','counts_no_zero','final_rating']]
rating_with_user
# Out:
#          userid        ISBN  location  age  counts  counts_no_zero  \
# 0        276925  0971880107     spain   22    2502             581
# 1        276925  0316666343     spain   22    1295             707
# 2        276925  0385504209     spain   22     883             487
# 3        276925  0804106304     spain   22     519             194
# 4        276925  002542730X     spain   22     171              77
# ...         ...         ...       ...  ...     ...             ...
# 1149775  109339  0801438543       usa   34       1               1
# 1149776  141040  0801491304   germany   34       1               1
# 1149777  263665  0801064562       usa   46       1               1
# 1149778  271450  0801064422       usa   46       1               1
# 1149779   54271  0801063248    canada   34       1               1
#
#          final_rating
# 0               2.705
# 1               6.327
# 2               6.544
# 3               5.630
# 4               5.660
# ...

# %% [markdown]
# ## Merging dataset Book and Rating_wuth_User

# %%
bookrate=rating_with_user.merge(book,on='ISBN')
bookrate
# Out:
#          userid        ISBN  location  age  counts  counts_no_zero  \
# 0        276925  0971880107     spain   22    2502             581
# 1        276939  0971880107    france   23    2502             581
# 2        276954  0971880107   germany   43    2502             581
# 3        277042  0971880107       usa   34    2502             581
# 4        277157  0971880107       usa   70    2502             581
# ...         ...         ...       ...  ...     ...             ...
# 1031127  109339  0801438543       usa   34       1               1
# 1031128  141040  0801491304   germany   34       1               1
# 1031129  263665  0801064562       usa   46       1               1
# 1031130  271450  0801064422       usa   46       1               1
# 1031131   54271  0801063248    canada   34       1               1
#
#          final_rating                                              title  \
# 0               2.705                                        Wild Animus
# ...

# %%
bookrate=bookrate[['userid','ISBN','title','author','publisher','year','location','age','counts','counts_no_zero','final_rating','image-m']]
bookrate = bookrate.drop_duplicates(subset=['ISBN']).reset_index()
bookrate
# Out:
#           index  userid        ISBN  \
# 0             0  276925  0971880107
# 1          2502  276925  0316666343
# 2          3797  276925  0385504209
# 3          4680  276925  0804106304
# 4          5199  276925  002542730X
# ...         ...     ...         ...
# 270142  1031127  109339  0801438543
# 270143  1031128  141040  0801491304
# 270144  1031129  263665  0801064562
# 270145  1031130  271450  0801064422
# 270146  1031131   54271  0801063248
#
#                                                     title              author  \
# 0                                             Wild Animus        Rich Shapero
# 1                               The Lovely Bones: A Novel        Alice Sebold
# 2                                       The Da Vinci Code           Dan Brown
# 3                                       The Joy Luck Club             Amy Tan
# 4       Politically Correct Bedtime Stories: Modern Ta...   James Finn Garner
# ...

# %%
book_with_rate=bookrate[['userid','ISBN','title','author','publisher','year','location','age','counts','counts_no_zero','final_rating','image-m']]
book_with_rate
# Out:
#         userid        ISBN                                              title  \
# 0       276925  0971880107                                        Wild Animus
# 1       276925  0316666343                          The Lovely Bones: A Novel
# 2       276925  0385504209                                  The Da Vinci Code
# 3       276925  0804106304                                  The Joy Luck Club
# 4       276925  002542730X  Politically Correct Bedtime Stories: Modern Ta...
# ...        ...         ...                                                ...
# 270142  109339  0801438543  Under the Black Umbrella: Voices from Colonial...
# 270143  141040  0801491304  The Complete Poems of Stephen Crane (Cornell P...
# 270144  263665  0801064562    Just Think: Nourish Your Mind to Feed Your Soul
# 270145  271450  0801064422  The Bumps Are What You Climb on: Encouragement...
# 270146   54271  0801063248  Growing Strong Daughters: Encouraging Girls to...
#
# ...

# %%
# sagricating with count of zero rating
populerbook=book_with_rate[book_with_rate['counts_no_zero']>=150].sort_values('final_rating',ascending=False).reset_index()
populerbook=populerbook.drop('index',axis=1)
populerbook.head(10)
# Out:
#    userid        ISBN                                              title  \
# 0    6251  043935806X  Harry Potter and the Order of the Phoenix (Boo...
# 1    2766  0446310786                              To Kill a Mockingbird
# 2  276939  059035342X  Harry Potter and the Sorcerer's Stone (Harry P...
# 3  277427  0345339681  The Hobbit : The Enchanting Prelude to The Lor...
# 4  277427  0439064872   Harry Potter and the Chamber of Secrets (Book 2)
# 5  276925  0385504209                                  The Da Vinci Code
# 6    6543  0345342968                                     Fahrenheit 451
# 7  277427  0385484518  Tuesdays with Morrie: An Old Man, a Young Man,...
# 8  277427  0142001740                            The Secret Life of Bees
# 9  276925  0316666343                          The Lovely Bones: A Novel
#
#            author                   publisher    year location  age  counts  \
# 0   J. K. Rowling                  Scholastic  2003.0      usa   32     334
# ...

# %% [markdown]
# ## Sorting Dataset For Usa

# %%
bookrate
# Out:
#           index  userid        ISBN  \
# 0             0  276925  0971880107
# 1          2502  276925  0316666343
# 2          3797  276925  0385504209
# 3          4680  276925  0804106304
# 4          5199  276925  002542730X
# ...         ...     ...         ...
# 270142  1031127  109339  0801438543
# 270143  1031128  141040  0801491304
# 270144  1031129  263665  0801064562
# 270145  1031130  271450  0801064422
# 270146  1031131   54271  0801063248
#
#                                                     title              author  \
# 0                                             Wild Animus        Rich Shapero
# 1                               The Lovely Bones: A Novel        Alice Sebold
# 2                                       The Da Vinci Code           Dan Brown
# 3                                       The Joy Luck Club             Amy Tan
# 4       Politically Correct Bedtime Stories: Modern Ta...   James Finn Garner
# ...

# %%
bookrate['location'].value_counts().to_frame().head(10)
# Out:
#                  location
#  usa               178764
#  canada             23383
#  united kingdom     12251
#  n/a                 9767
#  germany             9618
#  spain               6762
#  australia           6075
#  france              4401
# other                4011
#  new zealand         2228

# %%
#Sorting Usa Data From Bookrate Dataframe
user_usa=bookrate[bookrate['location']==' usa']

# selecting Required Colunms 
loc_with_rate=user_usa[['userid','ISBN','title','author','publisher','year','location','age','counts','counts_no_zero','final_rating','image-m']]
loc_with_rate
# Out:
#         userid        ISBN                                              title  \
# 111     277042  0671003755  She's Come Undone (Oprah's Book Club (Paperback))
# 112     277042  0380731851                                       Mystic River
# 113     277042  0312983271         Full House (Janet Evanovich's Full Series)
# 114     277042  0446611212                                   Violets Are Blue
# 115     277042  0446605484                  Roses Are Red (Alex Cross Novels)
# ...        ...         ...                                                ...
# 270140   91180  0800758307                                  Postmarked Heaven
# 270141   91180  0801064252                                       Face to Face
# 270142  109339  0801438543  Under the Black Umbrella: Voices from Colonial...
# 270144  263665  0801064562    Just Think: Nourish Your Mind to Feed Your Soul
# 270145  271450  0801064422  The Bumps Are What You Climb on: Encouragement...
#
# ...

# %%
# sagricating with count of zero rating
populer_usa=loc_with_rate[loc_with_rate['counts_no_zero']>=150].sort_values('final_rating',ascending=False).reset_index()
populer_usa=populer_usa.drop('index',axis=1)
populer_usa.head(10)
# Out:
#    userid        ISBN                                              title  \
# 0    6251  043935806X  Harry Potter and the Order of the Phoenix (Boo...
# 1    2766  0446310786                              To Kill a Mockingbird
# 2  277427  0345339681  The Hobbit : The Enchanting Prelude to The Lor...
# 3  277427  0439064872   Harry Potter and the Chamber of Secrets (Book 2)
# 4    6543  0345342968                                     Fahrenheit 451
# 5  277427  0385484518  Tuesdays with Morrie: An Old Man, a Young Man,...
# 6  277427  0142001740                            The Secret Life of Bees
# 7    6251  0060938455  Fast Food Nation: The Dark Side of the All-Ame...
# 8  277427  0345361792                            A Prayer for Owen Meany
# 9    1435  0446672211  Where the Heart Is (Oprah's Book Club (Paperba...
#
#            author                   publisher    year location  age  counts  \
# 0   J. K. Rowling                  Scholastic  2003.0      usa   32     334
# ...

# %% [markdown]
# ## Sorting Dataset For canada

# %%
# Sorting Users Frome Canada  
user_can=bookrate[bookrate['location']==' canada']

# Selecting Colums
rate_of_can=user_can[['userid','ISBN','title','author','publisher','year','location','age','counts','counts_no_zero','final_rating','image-m']]
rate_of_can
# Out:
#         userid        ISBN                                              title  \
# 186     277378  0312195516                The Red Tent (Bestselling Backlist)
# 187     277378  0684872153                    Angela's Ashes (MMP) : A Memoir
# 188     277378  0446608955                                 A Walk to Remember
# 189     277378  0804114986                          The Bonesetter's Daughter
# 190     277378  0553279378                    I Know Why the Caged Bird Sings
# ...        ...         ...                                                ...
# 270120   87980  078970210X                         Running a Perfect Web Site
# 270127  250644  0802006671              Corporate Crime: Contemporary Debates
# 270128   40522  0802064698                          A.M. Klein: Short Stories
# 270129  237153  0802085164  Blood on the Hills: The Canadian Army in the K...
# 270146   54271  0801063248  Growing Strong Daughters: Encouraging Girls to...
#
# ...

# %%
# Sorting without count of zero rating
populer_can=rate_of_can[rate_of_can['counts_no_zero']>=30].sort_values('final_rating',ascending=False).reset_index()
populer_can=populer_can.drop('index',axis=1)
populer_can.head(10)
# Out:
#    userid        ISBN                                           title  \
# 0  277378  0689817851                                    Go Ask Alice
# 1   21404  0345413369   The Subtle Knife (His Dark Materials, Book 2)
# 2  277378  0312195516             The Red Tent (Bestselling Backlist)
# 3  277378  0804114986                       The Bonesetter's Daughter
# 4  277378  0684872153                 Angela's Ashes (MMP) : A Memoir
# 5  277378  0446608955                              A Walk to Remember
# 6  277378  0553279378                 I Know Why the Caged Bird Sings
# 7   40958  031205436X  Generation X: Tales for an Accelerated Culture
# 8  277378  0671028375                                    Fatal Voyage
# 9  277378  0451137965                                         Thinner
#
#              author           publisher    year location  age  counts  \
# 0         Anonymous         Simon Pulse  1998.0   canada   33      87
# ...

# %% [markdown]
# ## Sorting Dataset For United Kingdom

# %%
# Sorting Data For United Kingdam Reader
user_uk=bookrate[bookrate['location']==' united kingdom']

# Selecting Columns 
rate_of_uk=user_uk[['userid','ISBN','title','author','publisher','year','location','age','counts','counts_no_zero','final_rating','image-m']]
rate_of_uk
# Out:
#         userid        ISBN                                              title  \
# 1095       901  0099771519                             Memoirs of a Geisha Uk
# 1096       901  000649840X                                      Angelas Ashes
# 1097       901  0349101779                                   The Wasp Factory
# 1098       901  0679745653  Breakfast at Tiffany's: And Three Stories (Fir...
# 1099       901  0349103232                                      The crow road
# ...        ...         ...                                                ...
# 270045  258646  0349115125                                      Broken Bodies
# 270046   24868  0349112363                                       Breeders Box
# 270047   23044  0349111049                                          Happy Now
# 270069   65464  0786914033  The Shattered Alliance (Ice Age Cycle, Book II...
# 270072   92775  0787109363                Colin Powell and the American Dream
#
# ...

# %%
# segregate with count of zero rating
populer_uk=rate_of_uk[rate_of_uk['counts_no_zero']>=30].sort_values('final_rating',ascending=False).reset_index()
populer_uk=populer_uk.drop('index',axis=1)
populer_uk.head(10)
# Out:
#    userid        ISBN                                              title  \
# 0    1025  0142000663  The Grapes of Wrath: John Steinbeck Centennial...
# 1   23902  0393312836      A Clockwork Orange (Norton Paperback Fiction)
# 2    1025  0330262130              Restaurant At the End of the Universe
# 3     901  0099771519                             Memoirs of a Geisha Uk
# 4    9381  038549081X                      The Handmaid's Tale : A Novel
# 5    1025  0380012863                        Jonathan Livingston Seagull
# 6    1025  068484267X                           Angela's Ashes: A Memoir
# 7    1025  0552996009                          Notes From a Small Planet
# 8    7105  0552998486                                           Chocolat
# 9    1025  0590660543            Northern Lights (His Dark Materials S.)
#
#             author                   publisher    year         location  age  \
# 0   John Steinbeck               Penguin Books  2002.0   united kingdom   33
# ...

# %% [markdown]
# ## Populer Book in World-wide, US,Canada,UK

# %%
# Populer Book in World-Wide
populerbook.head(10)
# Out:
#    userid        ISBN                                              title  \
# 0    6251  043935806X  Harry Potter and the Order of the Phoenix (Boo...
# 1    2766  0446310786                              To Kill a Mockingbird
# 2  276939  059035342X  Harry Potter and the Sorcerer's Stone (Harry P...
# 3  277427  0345339681  The Hobbit : The Enchanting Prelude to The Lor...
# 4  277427  0439064872   Harry Potter and the Chamber of Secrets (Book 2)
# 5  276925  0385504209                                  The Da Vinci Code
# 6    6543  0345342968                                     Fahrenheit 451
# 7  277427  0385484518  Tuesdays with Morrie: An Old Man, a Young Man,...
# 8  277427  0142001740                            The Secret Life of Bees
# 9  276925  0316666343                          The Lovely Bones: A Novel
#
#            author                   publisher    year location  age  counts  \
# 0   J. K. Rowling                  Scholastic  2003.0      usa   32     334
# ...

# %%
# Populer Book in USA Minimum rataing is 150
populer_usa.head(10)
# Out:
#    userid        ISBN                                              title  \
# 0    6251  043935806X  Harry Potter and the Order of the Phoenix (Boo...
# 1    2766  0446310786                              To Kill a Mockingbird
# 2  277427  0345339681  The Hobbit : The Enchanting Prelude to The Lor...
# 3  277427  0439064872   Harry Potter and the Chamber of Secrets (Book 2)
# 4    6543  0345342968                                     Fahrenheit 451
# 5  277427  0385484518  Tuesdays with Morrie: An Old Man, a Young Man,...
# 6  277427  0142001740                            The Secret Life of Bees
# 7    6251  0060938455  Fast Food Nation: The Dark Side of the All-Ame...
# 8  277427  0345361792                            A Prayer for Owen Meany
# 9    1435  0446672211  Where the Heart Is (Oprah's Book Club (Paperba...
#
#            author                   publisher    year location  age  counts  \
# 0   J. K. Rowling                  Scholastic  2003.0      usa   32     334
# ...

# %%
# Populer Book in Canada Minimum rataing is 30
populer_can.head(10)
# Out:
#    userid        ISBN                                           title  \
# 0  277378  0689817851                                    Go Ask Alice
# 1   21404  0345413369   The Subtle Knife (His Dark Materials, Book 2)
# 2  277378  0312195516             The Red Tent (Bestselling Backlist)
# 3  277378  0804114986                       The Bonesetter's Daughter
# 4  277378  0684872153                 Angela's Ashes (MMP) : A Memoir
# 5  277378  0446608955                              A Walk to Remember
# 6  277378  0553279378                 I Know Why the Caged Bird Sings
# 7   40958  031205436X  Generation X: Tales for an Accelerated Culture
# 8  277378  0671028375                                    Fatal Voyage
# 9  277378  0451137965                                         Thinner
#
#              author           publisher    year location  age  counts  \
# 0         Anonymous         Simon Pulse  1998.0   canada   33      87
# ...

# %%
# Populer Book in UK Minimum rataing is 30
populer_uk.head(10)
# Out:
#    userid        ISBN                                              title  \
# 0    1025  0142000663  The Grapes of Wrath: John Steinbeck Centennial...
# 1   23902  0393312836      A Clockwork Orange (Norton Paperback Fiction)
# 2    1025  0330262130              Restaurant At the End of the Universe
# 3     901  0099771519                             Memoirs of a Geisha Uk
# 4    9381  038549081X                      The Handmaid's Tale : A Novel
# 5    1025  0380012863                        Jonathan Livingston Seagull
# 6    1025  068484267X                           Angela's Ashes: A Memoir
# 7    1025  0552996009                          Notes From a Small Planet
# 8    7105  0552998486                                           Chocolat
# 9    1025  0590660543            Northern Lights (His Dark Materials S.)
#
#             author                   publisher    year         location  age  \
# 0   John Steinbeck               Penguin Books  2002.0   united kingdom   33
# ...

# %% [markdown]
# ## Sorting Populer Book by Year

# %%
## sorting Populer Book by Year
bookrate
# Out:
#           index  userid        ISBN  \
# 0             0  276925  0971880107
# 1          2502  276925  0316666343
# 2          3797  276925  0385504209
# 3          4680  276925  0804106304
# 4          5199  276925  002542730X
# ...         ...     ...         ...
# 270142  1031127  109339  0801438543
# 270143  1031128  141040  0801491304
# 270144  1031129  263665  0801064562
# 270145  1031130  271450  0801064422
# 270146  1031131   54271  0801063248
#
#                                                     title              author  \
# 0                                             Wild Animus        Rich Shapero
# 1                               The Lovely Bones: A Novel        Alice Sebold
# 2                                       The Da Vinci Code           Dan Brown
# 3                                       The Joy Luck Club             Amy Tan
# 4       Politically Correct Bedtime Stories: Modern Ta...   James Finn Garner
# ...

# %%
def conditions(i): #Apply Condition For Year Grouping/bins
    if i >= 1897 and i <=1925: return '1897_1925'
    if i >= 1926 and i <=1950: return '1926_1950'
    if i >= 1951 and i <=1975: return '1951_1975'
    if i >= 1976 and i <=2000: return '1976_2000' 
    if i >= 2001 and i <=2021: return '2001_2021'

bookrate['year_bin']=bookrate['year'].apply(conditions)

# %%
bookrate_year=bookrate[['ISBN','title','author','publisher','year','year_bin','location','age','counts','counts_no_zero','final_rating']]
bookrate_year
# Out:
#               ISBN                                              title  \
# 0       0971880107                                        Wild Animus
# 1       0316666343                          The Lovely Bones: A Novel
# 2       0385504209                                  The Da Vinci Code
# 3       0804106304                                  The Joy Luck Club
# 4       002542730X  Politically Correct Bedtime Stories: Modern Ta...
# ...            ...                                                ...
# 270142  0801438543  Under the Black Umbrella: Voices from Colonial...
# 270143  0801491304  The Complete Poems of Stephen Crane (Cornell P...
# 270144  0801064562    Just Think: Nourish Your Mind to Feed Your Soul
# 270145  0801064422  The Bumps Are What You Climb on: Encouragement...
# 270146  0801063248  Growing Strong Daughters: Encouraging Girls to...
#
#                     author                  publisher    year   year_bin  \
# ...

# %%
# Count of Year Bin of Hole Dataset
bookrate_year['year_bin'].value_counts().to_frame().head(10)
# Out:
#            year_bin
# 1976_2000    203049
# 2001_2021     59505
# 1951_1975      7271
# 1926_1950       229
# 1897_1925        93

# %% [markdown]
# ## Sorting Book On year Bin of 1897_1925

# %%
# Segrigating 1897 to 1925 Frome Bookrate
bookrate_year1925=bookrate_year[bookrate_year['year_bin']=='1897_1925']

# segregate with count of zero rating
populer_1925=bookrate_year1925[bookrate_year1925['counts_no_zero']>=3].sort_values('final_rating',ascending=False).reset_index()
populer_1925=populer_1925.drop('index',axis=1)
populer_1925.head(10)
# Out:
#          ISBN                                              title  \
# 0  0911662251  Kybalion: A Study of the Hermetic Philosophy o...
# 1  2253004014                                 Liasons Dangeruses
# 2  0440772095        RAMONA THE PEST (Ramona Quimby (Paperback))
# 3  186046310X                                               Silk
# 4  0684717603                The GREAT GATSBY (Scribner Classic)
# 5  0307021491                                Alice in Wonderland
# 6  0440745454                             HOW TO EAT FRIED WORMS
# 7  0307002101  My Little Golden Book of Cars and Trucks (Litt...
# 8  0307020630                            Animals Merry Christmas
# 9  0380789310                     The Twelve Crimes of Christmas
#
#                                     author  \
# 0                          Three Initiates
# 1  Pierre Ambroise Francois Choderl Laclos
# 2                           BEVERLY CLEARY
# 3                       Alessandro Baricco
# ...

# %% [markdown]
# ## Sorting Book On year Bin of 1926_1950

# %%
# Segrigating 1926 to 1950 Frome Bookrate
bookrate_year1950=bookrate_year[bookrate_year['year_bin']=='1926_1950']

# segregate with count of zero rating
populer_1950=bookrate_year1950[bookrate_year1950['counts_no_zero']>=5].sort_values('final_rating',ascending=False).reset_index()
populer_1950=populer_1950.drop('index',axis=1)
populer_1950.head(10)
# Out:
#          ISBN                                              title  \
# 0  0395071224                                         The Hobbit
# 1  0060263954             Stuart Little 60th Anniversary Edition
# 2  0684717972                                   Farewell to Arms
# 3  0553213601               Cyrano De Bergerac (Bantam Classics)
# 4  0448060043  Alice in Wonderland and Through the Looking Gl...
# 5  2710300257                 Antigone (French Language Edition)
# 6  0448095017  The Secret of the Old Clock (Nancy Drew Myster...
# 7  0448089033  The Secret of the Old Mill (The Hardy Boys Mys...
# 8  0060901012    Brave New World &amp; Brave New World Revisited
# 9  0448095076  The Clue in the Diary (Nancy Drew Mystery Stor...
#
#                      author                 publisher    year   year_bin  \
# 0          J. R. R. Tolkien  Houghton Mifflin Company  1938.0  1926_1950
# 1               E. B. White             HarperCollins  1945.0  1926_1950
# ...

# %% [markdown]
# ## Sorting Book On year Bin of 1951_1975

# %%
# Segrigating 1951 to 1975 Frome Bookrate
bookrate_year1975=bookrate_year[bookrate_year['year_bin']=='1951_1975']

# segregate with count of zero rating
populer_1975=bookrate_year1975[bookrate_year1975['counts_no_zero']>=20].sort_values('final_rating',ascending=False).reset_index()
populer_1975=populer_1975.drop('index',axis=1)
populer_1975.head(10)
# Out:
#          ISBN                                              title  \
# 0  0060256672       Where the Sidewalk Ends : Poems and Drawings
# 1  0060256656                                    The Giving Tree
# 2  039480001X                                 The Cat in the Hat
# 3  0156528207                                  The Little Prince
# 4  0394800168  Green Eggs and Ham (I Can Read It All by Mysel...
# 5  0064400557                   Charlotte's Web (Trophy Newbery)
# 6  0394404289                                        The Prophet
# 7  0064400042                         On the Banks of Plum Creek
# 8  0553213695                The Metamorphosis (Bantam Classics)
# 9  038001503X                      One Hundred Years of Solitude
#
#                       author                             publisher    year  \
# 0           Shel Silverstein                         HarperCollins  1974.0
# 1           Shel Silverstein              HarperCollins Publishers  1964.0
# ...

# %% [markdown]
# ## Sorting Book On year Bin of 1976_2000

# %%
# Segrigating 1976 to 2000 Frome Bookrate
bookrate_year2000=bookrate_year[bookrate_year['year_bin']=='1976_2000']

# segregate with count of zero rating
populer_2000=bookrate_year2000[bookrate_year2000['counts_no_zero']>=50].sort_values('final_rating',ascending=False).reset_index()
populer_2000=populer_2000.drop('index',axis=1)
populer_2000.head(10)
# Out:
#          ISBN                                              title  \
# 0  0439139597       Harry Potter and the Goblet of Fire (Book 4)
# 1  0439064864   Harry Potter and the Chamber of Secrets (Book 2)
# 2  0439136350  Harry Potter and the Prisoner of Azkaban (Book 3)
# 3  0590353403     Harry Potter and the Sorcerer's Stone (Book 1)
# 4  0812550706      Ender's Game (Ender Wiggins Saga (Paperback))
# 5  0446310786                              To Kill a Mockingbird
# 6  059035342X  Harry Potter and the Sorcerer's Stone (Harry P...
# 7  0345339681  The Hobbit : The Enchanting Prelude to The Lor...
# 8  0345339738  The Return of the King (The Lord of the Rings,...
# 9  0441172717                        Dune (Remembering Tomorrow)
#
#              author                   publisher    year   year_bin location  \
# 0     J. K. Rowling                  Scholastic  2000.0  1976_2000   taiwan
# 1     J. K. Rowling                  Scholastic  1999.0  1976_2000   taiwan
# ...

# %% [markdown]
# ## Sorting Book On year Bin of 2001_2021

# %%
# Segrigating 2001 to 2021 Frome Bookrate
bookrate_year2021=bookrate_year[bookrate_year['year_bin']=='2001_2021']

# segregate with count of zero rating
populer_2021=bookrate_year2021[bookrate_year2021['counts_no_zero']>=50].sort_values('final_rating',ascending=False).reset_index()
populer_2021=populer_2021.drop('index',axis=1)
populer_2021.head(10)
# Out:
#          ISBN                                              title  \
# 0  1844262553                                               Free
# 1  043935806X  Harry Potter and the Order of the Phoenix (Boo...
# 2  0439136369  Harry Potter and the Prisoner of Azkaban (Book 3)
# 3  0439139600       Harry Potter and the Goblet of Fire (Book 4)
# 4  0670894605                            The Secret Life of Bees
# 5  043936213X     Harry Potter and the Sorcerer's Stone (Book 1)
# 6  1400032717  The Curious Incident of the Dog in the Night-T...
# 7  0743227441                              The Other Boleyn Girl
# 8  0142004235                   East of Eden (Oprah's Book Club)
# 9  0385504209                                  The Da Vinci Code
#
#              author              publisher    year   year_bin location  age  \
# 0      Paul Vincent     Upfront Publishing  2003.0  2001_2021      n/a   34
# 1     J. K. Rowling             Scholastic  2003.0  2001_2021      usa   32
# ...

# %% [markdown]
# ## Sorting Populer Book on Basis of Year Bin Top 10 Head

# %%
# Sorting Book On year Bin of 1897_1925
populer_1925.head(10)
# Out:
#          ISBN                                              title  \
# 0  0911662251  Kybalion: A Study of the Hermetic Philosophy o...
# 1  2253004014                                 Liasons Dangeruses
# 2  0440772095        RAMONA THE PEST (Ramona Quimby (Paperback))
# 3  186046310X                                               Silk
# 4  0684717603                The GREAT GATSBY (Scribner Classic)
# 5  0307021491                                Alice in Wonderland
# 6  0440745454                             HOW TO EAT FRIED WORMS
# 7  0307002101  My Little Golden Book of Cars and Trucks (Litt...
# 8  0307020630                            Animals Merry Christmas
# 9  0380789310                     The Twelve Crimes of Christmas
#
#                                     author  \
# 0                          Three Initiates
# 1  Pierre Ambroise Francois Choderl Laclos
# 2                           BEVERLY CLEARY
# 3                       Alessandro Baricco
# ...

# %%
# Sorting Book On year Bin of 1926_1950
populer_1950.head(10)
# Out:
#          ISBN                                              title  \
# 0  0395071224                                         The Hobbit
# 1  0060263954             Stuart Little 60th Anniversary Edition
# 2  0684717972                                   Farewell to Arms
# 3  0553213601               Cyrano De Bergerac (Bantam Classics)
# 4  0448060043  Alice in Wonderland and Through the Looking Gl...
# 5  2710300257                 Antigone (French Language Edition)
# 6  0448095017  The Secret of the Old Clock (Nancy Drew Myster...
# 7  0448089033  The Secret of the Old Mill (The Hardy Boys Mys...
# 8  0060901012    Brave New World &amp; Brave New World Revisited
# 9  0448095076  The Clue in the Diary (Nancy Drew Mystery Stor...
#
#                      author                 publisher    year   year_bin  \
# 0          J. R. R. Tolkien  Houghton Mifflin Company  1938.0  1926_1950
# 1               E. B. White             HarperCollins  1945.0  1926_1950
# ...

# %%
# Sorting Book On year Bin of 1951_1975
populer_1975.head(10)
# Out:
#          ISBN                                              title  \
# 0  0060256672       Where the Sidewalk Ends : Poems and Drawings
# 1  0060256656                                    The Giving Tree
# 2  039480001X                                 The Cat in the Hat
# 3  0156528207                                  The Little Prince
# 4  0394800168  Green Eggs and Ham (I Can Read It All by Mysel...
# 5  0064400557                   Charlotte's Web (Trophy Newbery)
# 6  0394404289                                        The Prophet
# 7  0064400042                         On the Banks of Plum Creek
# 8  0553213695                The Metamorphosis (Bantam Classics)
# 9  038001503X                      One Hundred Years of Solitude
#
#                       author                             publisher    year  \
# 0           Shel Silverstein                         HarperCollins  1974.0
# 1           Shel Silverstein              HarperCollins Publishers  1964.0
# ...

# %%
## Sorting Book On year Bin of 1976_2000
populer_2000.head(10)
# Out:
#          ISBN                                              title  \
# 0  0439139597       Harry Potter and the Goblet of Fire (Book 4)
# 1  0439064864   Harry Potter and the Chamber of Secrets (Book 2)
# 2  0439136350  Harry Potter and the Prisoner of Azkaban (Book 3)
# 3  0590353403     Harry Potter and the Sorcerer's Stone (Book 1)
# 4  0812550706      Ender's Game (Ender Wiggins Saga (Paperback))
# 5  0446310786                              To Kill a Mockingbird
# 6  059035342X  Harry Potter and the Sorcerer's Stone (Harry P...
# 7  0345339681  The Hobbit : The Enchanting Prelude to The Lor...
# 8  0345339738  The Return of the King (The Lord of the Rings,...
# 9  0441172717                        Dune (Remembering Tomorrow)
#
#              author                   publisher    year   year_bin location  \
# 0     J. K. Rowling                  Scholastic  2000.0  1976_2000   taiwan
# 1     J. K. Rowling                  Scholastic  1999.0  1976_2000   taiwan
# ...

# %%
# Sorting Book On year Bin of 2001_2021
populer_2021.head(10)
# Out:
#          ISBN                                              title  \
# 0  1844262553                                               Free
# 1  043935806X  Harry Potter and the Order of the Phoenix (Boo...
# 2  0439136369  Harry Potter and the Prisoner of Azkaban (Book 3)
# 3  0439139600       Harry Potter and the Goblet of Fire (Book 4)
# 4  0670894605                            The Secret Life of Bees
# 5  043936213X     Harry Potter and the Sorcerer's Stone (Book 1)
# 6  1400032717  The Curious Incident of the Dog in the Night-T...
# 7  0743227441                              The Other Boleyn Girl
# 8  0142004235                   East of Eden (Oprah's Book Club)
# 9  0385504209                                  The Da Vinci Code
#
#              author              publisher    year   year_bin location  age  \
# 0      Paul Vincent     Upfront Publishing  2003.0  2001_2021      n/a   34
# 1     J. K. Rowling             Scholastic  2003.0  2001_2021      usa   32
# ...

# %% [markdown]
# ## Sortong Populer Book On the Age Basis

# %%
bookrate
# Out:
#           index  userid        ISBN  \
# 0             0  276925  0971880107
# 1          2502  276925  0316666343
# 2          3797  276925  0385504209
# 3          4680  276925  0804106304
# 4          5199  276925  002542730X
# ...         ...     ...         ...
# 270142  1031127  109339  0801438543
# 270143  1031128  141040  0801491304
# 270144  1031129  263665  0801064562
# 270145  1031130  271450  0801064422
# 270146  1031131   54271  0801063248
#
#                                                     title              author  \
# 0                                             Wild Animus        Rich Shapero
# 1                               The Lovely Bones: A Novel        Alice Sebold
# 2                                       The Da Vinci Code           Dan Brown
# 3                                       The Joy Luck Club             Amy Tan
# 4       Politically Correct Bedtime Stories: Modern Ta...   James Finn Garner
# ...

# %%
bookrate['age'].describe()
# Out:
# count    270147.000000
# mean         37.135274
# std          10.476074
# min          10.000000
# 25%          31.000000
# 50%          34.000000
# 75%          43.000000
# max          85.000000
# Name: age, dtype: float64

# %%
def conditions(i): #Apply Condition For Age Grouping/Bins
    if i >= 10 and i <=25: return 'teen'
    if i >= 26 and i <=40: return 'young'
    if i >= 41 and i <=55: return 'middle_aged'
    if i >= 56 and i <=70: return 'adult' 
    if i >= 71 and i <=85: return 'aged'

bookrate['age_bin']=bookrate['age'].apply(conditions)

# %%
bookrate_age=bookrate[['ISBN','title','author','publisher','year','location','age','age_bin','counts','counts_no_zero','final_rating']]
bookrate_age
# Out:
#               ISBN                                              title  \
# 0       0971880107                                        Wild Animus
# 1       0316666343                          The Lovely Bones: A Novel
# 2       0385504209                                  The Da Vinci Code
# 3       0804106304                                  The Joy Luck Club
# 4       002542730X  Politically Correct Bedtime Stories: Modern Ta...
# ...            ...                                                ...
# 270142  0801438543  Under the Black Umbrella: Voices from Colonial...
# 270143  0801491304  The Complete Poems of Stephen Crane (Cornell P...
# 270144  0801064562    Just Think: Nourish Your Mind to Feed Your Soul
# 270145  0801064422  The Bumps Are What You Climb on: Encouragement...
# 270146  0801063248  Growing Strong Daughters: Encouraging Girls to...
#
#                     author                  publisher    year  location  age  \
# ...

# %%
# Count of Ager Bin of Hole Dataset
bookrate_age['age_bin'].value_counts().to_frame()
# Out:
#              age_bin
# young         162371
# middle_aged    60225
# teen           27783
# adult          19005
# aged             763

# %% [markdown]
# ## Sorting Book On Age Bin of Teen 10-25

# %%
# Sorting datset for teen Reader
bookrate_age_teen=bookrate_age[bookrate_age['age_bin']=='teen']

# segregate with count of zero rating
populer_teen=bookrate_age_teen[bookrate_age_teen['counts_no_zero']>=30].sort_values('final_rating',ascending=False).reset_index()
populer_teen=populer_teen.drop('index',axis=1)
populer_teen
# Out:
#           ISBN                                              title  \
# 0   059035342X  Harry Potter and the Sorcerer's Stone (Harry P...
# 1   0553296981              Anne Frank: The Diary of a Young Girl
# 2   0805062971                                         Fight Club
# 3   0385504209                                  The Da Vinci Code
# 4   0316666343                          The Lovely Bones: A Novel
# 5   0142001430                                    Year of Wonders
# 6   0441000916  The Laughing Corpse (Anita Blake Vampire Hunte...
# 7   0099771519                             Memoirs of a Geisha Uk
# 8   068483376X                               Succulent Wild Woman
# 9   0345325818                                   The Silmarillion
# 10  0345391810  The Restaurant at the End of the Universe (Hit...
# 11  0452282152                          Girl with a Pearl Earring
# 12  0413537900        The Secret Diary of Adrian Mole Aged 13 3/4
# ...

# %% [markdown]
# ## Sorting Book On Age Bin of Young 26-40

# %%
# Sorting datset for Young Reader 
bookrate_young=bookrate_age[bookrate_age['age_bin']=='young']

# segregate with count of zero rating
populer_young=bookrate_young[bookrate_young['counts_no_zero']>=30].sort_values('final_rating',ascending=False).reset_index()
populer_young=populer_young.drop('index',axis=1)
populer_young
# Out:
#            ISBN                                              title  \
# 0    1844262553                                               Free
# 1    0439139597       Harry Potter and the Goblet of Fire (Book 4)
# 2    0060248025                                         Falling Up
# 3    0439064864   Harry Potter and the Chamber of Secrets (Book 2)
# 4    0439136350  Harry Potter and the Prisoner of Azkaban (Book 3)
# ..          ...                                                ...
# 881  080213825X                                       Four Blondes
# 882  0425192733  Portrait of a Killer: Jack the Ripper-- Case C...
# 883  039914739X                                       Isle of Dogs
# 884  0451203895                                          4 Blondes
# 885  0425182908                                       Isle of Dogs
#
#                         author                 publisher    year location  \
# 0                 Paul Vincent        Upfront Publishing  2003.0      n/a
# ...

# %% [markdown]
# ## Sorting Book On Age Bin of Middle Aged 41-55

# %%
# Sorting datset for Middle Aged Reader
bookrate_middle_aged=bookrate_age[bookrate_age['age_bin']=='middle_aged']

# segregate with count of zero rating
populer_middle_aged=bookrate_middle_aged[bookrate_middle_aged['counts_no_zero']>=30].sort_values('final_rating',ascending=False).reset_index()
populer_middle_aged=populer_middle_aged.drop('index',axis=1)
populer_middle_aged
# Out:
#            ISBN                                              title  \
# 0    0877017883  Griffin &amp; Sabine: An Extraordinary Corresp...
# 1    0439136369  Harry Potter and the Prisoner of Azkaban (Book 3)
# 2    0811801802  Sabine's Notebook: In Which the Extraordinary ...
# 3    043936213X     Harry Potter and the Sorcerer's Stone (Book 1)
# 4    0446310786                              To Kill a Mockingbird
# ..          ...                                                ...
# 177  0425116840     The Cardinal of the Kremlin (Jack Ryan Novels)
# 178  0440224594                                 The Return Journey
# 179  0553292722                                       Still Waters
# 180  031298328X          Full Tilt (Janet Evanovich's Full Series)
# 181  0446516538                           Slow Waltz in Cedar Bend
#
#                   author                   publisher    year location  age  \
# 0           Nick Bantock             Chronicle Books  1991.0      usa   48
# ...

# %% [markdown]
# ## Sorting Book On Age Bin of Adult 56-70

# %%
# Sorting datset for Adult Reader
bookrate_adult=bookrate_age[bookrate_age['age_bin']=='adult']

# segregate with count of zero rating
populer_adult=bookrate_adult[bookrate_adult['counts_no_zero']>=30].sort_values('final_rating',ascending=False).reset_index()
populer_adult=populer_adult.drop('index',axis=1)
populer_adult
# Out:
#           ISBN                                              title  \
# 0   0316154059                                      City of Bones
# 1   0156007754                           Blindness (Harvest Book)
# 2   0679732411                                  Gift from the Sea
# 3   0842329250  Soul Harvest: The World Takes Sides (Left Behi...
# 4   0842329269  Apollyon: The Destroyer Is Unleashed (Left Beh...
# 5   059030271X                                    Charlotte's Web
# 6   0671027360                                Angels &amp; Demons
# 7   0440439884                        Island of the Blue Dolphins
# 8   0842329129  Left Behind: A Novel of the Earth's Last Days ...
# 9   0345441036                                        Black House
# 10  0399148639                                        Mortal Prey
# 11  0743486226                                Angels &amp; Demons
# 12  0684867621            The Girl Who Loved Tom Gordon : A Novel
# ...

# %% [markdown]
# ## Sorting Book On Age Bin of Aged Reader 71-85

# %%
# Sorting datset for Aged Reader
bookrate_aged=bookrate_age[bookrate_age['age_bin']=='aged']

# segregate with count of zero rating
populer_aged=bookrate_aged[bookrate_aged['counts_no_zero']>=3].sort_values('final_rating',ascending=False).reset_index()
populer_aged=populer_aged.drop('index',axis=1)
populer_aged
# Out:
#           ISBN                                              title  \
# 0   091482967X                          The Blessings Already Are
# 1   0060182571  Modoc: The True Story of the Greatest Elephant...
# 2   0312853807                                        Zero Coupon
# 3   080215185X                    Teach Us to Outgrow Our Madness
# 4   1400050588  Songs of the Gorilla Nation : My Journey Throu...
# 5   1565921240                        Building Internet Firewalls
# 6   0345438221                                   Lines of Defense
# 7   076111937X                                     Amazing Gracie
# 8   0679416498                                             Mexico
# 9   0060094109                                   Air Battle Force
# 10  0394407571                        A Flag for Sunrise: A Novel
# 11  0786701420                                     Eating Pavlova
# 12  0374150036                        The Evening Wolves: A Novel
# ...

# %% [markdown]
# ## Sorting Populer Book Top 10 On basis of Age Bin

# %%
# Sorting Book On year Bin of Teen >=30
populer_teen.head(10)
# Out:
#          ISBN                                              title  \
# 0  059035342X  Harry Potter and the Sorcerer's Stone (Harry P...
# 1  0553296981              Anne Frank: The Diary of a Young Girl
# 2  0805062971                                         Fight Club
# 3  0385504209                                  The Da Vinci Code
# 4  0316666343                          The Lovely Bones: A Novel
# 5  0142001430                                    Year of Wonders
# 6  0441000916  The Laughing Corpse (Anita Blake Vampire Hunte...
# 7  0099771519                             Memoirs of a Geisha Uk
# 8  068483376X                               Succulent Wild Woman
# 9  0345325818                                   The Silmarillion
#
#                 author               publisher    year         location  age  \
# 0        J. K. Rowling  Arthur A. Levine Books  1999.0           france   23
# 1           ANNE FRANK                  Bantam  1993.0         malaysia   22
# ...

# %%
# Sorting Book On year Bin of Young >=30
populer_young.head(10)
# Out:
#          ISBN                                              title  \
# 0  1844262553                                               Free
# 1  0439139597       Harry Potter and the Goblet of Fire (Book 4)
# 2  0060248025                                         Falling Up
# 3  0439064864   Harry Potter and the Chamber of Secrets (Book 2)
# 4  0439136350  Harry Potter and the Prisoner of Azkaban (Book 3)
# 5  0590353403     Harry Potter and the Sorcerer's Stone (Book 1)
# 6  0618002227  The Fellowship of the Ring (The Lord of the Ri...
# 7  0385199570         The Stand (The Complete and Uncut Edition)
# 8  039480001X                                 The Cat in the Hat
# 9  0156528207                                  The Little Prince
#
#                       author                             publisher    year  \
# 0               Paul Vincent                    Upfront Publishing  2003.0
# 1              J. K. Rowling                            Scholastic  2000.0
# ...

# %%
# Sorting Book On year Bin of Middle Aged >=30
populer_middle_aged.head(10)
# Out:
#          ISBN                                              title  \
# 0  0877017883  Griffin &amp; Sabine: An Extraordinary Corresp...
# 1  0439136369  Harry Potter and the Prisoner of Azkaban (Book 3)
# 2  0811801802  Sabine's Notebook: In Which the Extraordinary ...
# 3  043936213X     Harry Potter and the Sorcerer's Stone (Book 1)
# 4  0446310786                              To Kill a Mockingbird
# 5  0345339681  The Hobbit : The Enchanting Prelude to The Lor...
# 6  038548951X                                 Sister of My Heart
# 7  0441172717                        Dune (Remembering Tomorrow)
# 8  0440219078                 The Giver (21st Century Reference)
# 9  0446677450  Rich Dad, Poor Dad: What the Rich Teach Their ...
#
#                        author                   publisher    year location  \
# 0                Nick Bantock             Chronicle Books  1991.0      usa
# 1               J. K. Rowling                  Scholastic  2001.0      usa
# ...

# %%
# Sorting Book On year Bin of Adult >=30
populer_adult.head(10)
# Out:
#          ISBN                                              title  \
# 0  0316154059                                      City of Bones
# 1  0156007754                           Blindness (Harvest Book)
# 2  0679732411                                  Gift from the Sea
# 3  0842329250  Soul Harvest: The World Takes Sides (Left Behi...
# 4  0842329269  Apollyon: The Destroyer Is Unleashed (Left Beh...
# 5  059030271X                                    Charlotte's Web
# 6  0671027360                                Angels &amp; Demons
# 7  0440439884                        Island of the Blue Dolphins
# 8  0842329129  Left Behind: A Novel of the Earth's Last Days ...
# 9  0345441036                                        Black House
#
#                   author                      publisher    year  location  \
# 0       Michael Connelly                   Warner Books  2002.0       usa
# 1          Jose Saramago                  Harvest Books  1999.0   finland
# ...

# %%
# Sorting Book On year Bin of Aged >=3
populer_aged.head(10)
# Out:
#          ISBN                                              title  \
# 0  091482967X                          The Blessings Already Are
# 1  0060182571  Modoc: The True Story of the Greatest Elephant...
# 2  0312853807                                        Zero Coupon
# 3  080215185X                    Teach Us to Outgrow Our Madness
# 4  1400050588  Songs of the Gorilla Nation : My Journey Throu...
# 5  1565921240                        Building Internet Firewalls
# 6  0345438221                                   Lines of Defense
# 7  076111937X                                     Amazing Gracie
# 8  0679416498                                             Mexico
# 9  0060094109                                   Air Battle Force
#
#                    author                       publisher    year  location  \
# 0             John Morton                Mandeville Press  2000.0     other
# 1            Ralph Helfer  HarperCollins Children's Books  1997.0     other
# ...

# %% [markdown]
# ## Segrigating Usa Data Frome Bookrate Data set

# %%
# Segrigating Usa Data Frome Bookrate Data set
user_usa=bookrate[bookrate['location']==' usa']

#selecting Requierd data set
bookrate_age_usa=user_usa[['ISBN','title','author','publisher','year','year_bin','location','age','age_bin','counts','counts_no_zero','final_rating']]
bookrate_age_usa
# Out:
#               ISBN                                              title  \
# 111     0671003755  She's Come Undone (Oprah's Book Club (Paperback))
# 112     0380731851                                       Mystic River
# 113     0312983271         Full House (Janet Evanovich's Full Series)
# 114     0446611212                                   Violets Are Blue
# 115     0446605484                  Roses Are Red (Alex Cross Novels)
# ...            ...                                                ...
# 270140  0800758307                                  Postmarked Heaven
# 270141  0801064252                                       Face to Face
# 270142  0801438543  Under the Black Umbrella: Voices from Colonial...
# 270144  0801064562    Just Think: Nourish Your Mind to Feed Your Soul
# 270145  0801064422  The Bumps Are What You Climb on: Encouragement...
#
#                     author                 publisher    year   year_bin  \
# ...

# %%
# Count of Age Bin of USA Reader
bookrate_age_usa['age_bin'].value_counts().to_frame()
# Out:
#              age_bin
# young          99696
# middle_aged    46975
# teen           16261
# adult          15279
# aged             553

# %%
# Count of Year Bin of USA Reader
bookrate_age_usa['year_bin'].value_counts().to_frame()
# Out:
#            year_bin
# 1976_2000    137530
# 2001_2021     36198
# 1951_1975      4819
# 1926_1950       156
# 1897_1925        61

# %% [markdown]
# ## Sorting Populer Book On Age Bin of Teen 10-25

# %%
## Sorting Book On Age Bin of Teen
bookrate_usa_teen=bookrate_age_usa[bookrate_age_usa['age_bin']=='teen']

# segregate with count of zero rating
populer_usa_teen=bookrate_usa_teen[bookrate_usa_teen['counts_no_zero']>=30].sort_values('final_rating',ascending=False).reset_index()
populer_usa_teen=populer_usa_teen.drop('index',axis=1)
populer_usa_teen.head(10)
# Out:
#          ISBN                                              title  \
# 0  0805062971                                         Fight Club
# 1  0142001430                                    Year of Wonders
# 2  068483376X                               Succulent Wild Woman
# 3  0452282152                          Girl with a Pearl Earring
# 4  0671880187                                            Kitchen
# 5  0385722206  Balzac and the Little Chinese Seamstress : A N...
# 6  0671250671  ROAD LESS TRAVELED : A New Psychology of Love,...
# 7  0451153553                                             Misery
# 8  006099486X  The Professor and the Madman: A Tale of Murder...
# 9  0671021001              She's Come Undone (Oprah's Book Club)
#
#              author                publisher    year   year_bin location  age  \
# 0   Chuck Palahniuk                Owl Books  1999.0  1976_2000      usa   25
# 1  Geraldine Brooks            Penguin Books  2002.0  2001_2021      usa   25
# ...

# %% [markdown]
# ## Sorting Populer Book On Age Bin of Young 26-40

# %%
## Sorting Book On Age Bin of Young
bookrate_usa_young=bookrate_age_usa[bookrate_age_usa['age_bin']=='young']

# segregate with count of zero rating
populer_usa_young=bookrate_usa_young[bookrate_usa_young['counts_no_zero']>=30].sort_values('final_rating',ascending=False).reset_index()
populer_usa_young=populer_usa_young.drop('index',axis=1)
populer_usa_young.head(10)
# Out:
#          ISBN                                              title  \
# 0  0060248025                                         Falling Up
# 1  0590353403     Harry Potter and the Sorcerer's Stone (Book 1)
# 2  039480001X                                 The Cat in the Hat
# 3  0156528207                                  The Little Prince
# 4  043935806X  Harry Potter and the Order of the Phoenix (Boo...
# 5  0618129022            The Lord of the Rings (Movie Art Cover)
# 6  0439139600       Harry Potter and the Goblet of Fire (Book 4)
# 7  0670894605                            The Secret Life of Bees
# 8  0618002219                The Hobbit: or There and Back Again
# 9  0679785892  Fear and Loathing in Las Vegas : A Savage Jour...
#
#                       author                             publisher    year  \
# 0           Shel Silverstein                         HarperCollins  1996.0
# 1              J. K. Rowling                            Scholastic  1998.0
# ...

# %% [markdown]
# ## Sorting Populer Book On Age Bin of Middel Aged 41-55

# %%
## Sorting Book On Age Bin of Young
bookrate_usa_midage=bookrate_age_usa[bookrate_age_usa['age_bin']=='middle_aged']

# segregate with count of zero rating
populer_usa_midage=bookrate_usa_midage[bookrate_usa_midage['counts_no_zero']>=30].sort_values('final_rating',ascending=False).reset_index()
populer_usa_midage=populer_usa_midage.drop('index',axis=1)
populer_usa_midage.head(10)
# Out:
#          ISBN                                              title  \
# 0  0877017883  Griffin &amp; Sabine: An Extraordinary Corresp...
# 1  0439136369  Harry Potter and the Prisoner of Azkaban (Book 3)
# 2  0811801802  Sabine's Notebook: In Which the Extraordinary ...
# 3  043936213X     Harry Potter and the Sorcerer's Stone (Book 1)
# 4  0446310786                              To Kill a Mockingbird
# 5  0345339681  The Hobbit : The Enchanting Prelude to The Lor...
# 6  038548951X                                 Sister of My Heart
# 7  0441172717                        Dune (Remembering Tomorrow)
# 8  0440219078                 The Giver (21st Century Reference)
# 9  0446677450  Rich Dad, Poor Dad: What the Rich Teach Their ...
#
#                        author                   publisher    year   year_bin  \
# 0                Nick Bantock             Chronicle Books  1991.0  1976_2000
# 1               J. K. Rowling                  Scholastic  2001.0  2001_2021
# ...

# %% [markdown]
# ## Sorting Populer Book On Age Bin of Adult 56-70

# %%
## Sorting Book On Age Bin of Young
bookrate_usa_adult=bookrate_age_usa[bookrate_age_usa['age_bin']=='adult']

# segregate with count of zero rating
populer_usa_adult=bookrate_usa_adult[bookrate_usa_adult['counts_no_zero']>=30].sort_values('final_rating',ascending=False).reset_index()
populer_usa_adult=populer_usa_adult.drop('index',axis=1)
populer_usa_adult.head(10)
# Out:
#          ISBN                                              title  \
# 0  0316154059                                      City of Bones
# 1  0679732411                                  Gift from the Sea
# 2  0842329250  Soul Harvest: The World Takes Sides (Left Behi...
# 3  0842329269  Apollyon: The Destroyer Is Unleashed (Left Beh...
# 4  059030271X                                    Charlotte's Web
# 5  0671027360                                Angels &amp; Demons
# 6  0440439884                        Island of the Blue Dolphins
# 7  0842329129  Left Behind: A Novel of the Earth's Last Days ...
# 8  0345441036                                        Black House
# 9  0399148639                                        Mortal Prey
#
#                   author                      publisher    year   year_bin  \
# 0       Michael Connelly                   Warner Books  2002.0  2001_2021
# 1  Anne Morrow Lindbergh                 Pantheon Books  1991.0  1976_2000
# ...

# %% [markdown]
# ## Sorting Populer Book On Age Bin of Aged 71-85

# %%
## Sorting Book On Age Bin of Young
bookrate_usa_aged=bookrate_age_usa[bookrate_age_usa['age_bin']=='aged']

# segregate with count of zero rating
populer_usa_aged=bookrate_usa_aged[bookrate_usa_aged['counts_no_zero']>=3].sort_values('final_rating',ascending=False).reset_index()
populer_usa_aged=populer_usa_aged.drop('index',axis=1)
populer_usa_aged.head(10)
# Out:
#          ISBN                                              title  \
# 0  080215185X                    Teach Us to Outgrow Our Madness
# 1  1400050588  Songs of the Gorilla Nation : My Journey Throu...
# 2  1565921240                        Building Internet Firewalls
# 3  076111937X                                     Amazing Gracie
# 4  0679416498                                             Mexico
# 5  0312193726  Wrong Information Is Being Given Out at Prince...
# 6  0553234722                     Greatest Salesman In the World
# 7  0373825943  Perfect Solution (Heart Of The West) (Heart of...
# 8  0670865788                                          The Atlas
# 9  0394534077                                        Berlin Game
#
#                    author              publisher    year   year_bin location  \
# 0            Kenzaburo Oe            Grove Press  1977.0  1976_2000      usa
# 1  DAWN PHD PRINCE-HUGHES                Harmony  2004.0  2001_2021      usa
# ...

# %% [markdown]
# ## Sorting USA Populer Book On Year Column

# %%
user_usa
# Out:
#           index  userid        ISBN  \
# 111        6964  277042  0671003755
# 112        7410  277042  0380731851
# 113        7699  277042  0312983271
# 114        7956  277042  0446611212
# 115        8208  277042  0446605484
# ...         ...     ...         ...
# 270140  1031125   91180  0800758307
# 270141  1031126   91180  0801064252
# 270142  1031127  109339  0801438543
# 270144  1031129  263665  0801064562
# 270145  1031130  271450  0801064422
#
#                                                     title              author  \
# 111     She's Come Undone (Oprah's Book Club (Paperback))          Wally Lamb
# 112                                          Mystic River       Dennis Lehane
# 113            Full House (Janet Evanovich's Full Series)     Janet Evanovich
# 114                                      Violets Are Blue     James Patterson
# 115                     Roses Are Red (Alex Cross Novels)     James Patterson
# ...

# %%
usa_year=user_usa[['ISBN','title','author','publisher','year','year_bin','location','age','age_bin','counts','counts_no_zero','final_rating']]
usa_year
# Out:
#               ISBN                                              title  \
# 111     0671003755  She's Come Undone (Oprah's Book Club (Paperback))
# 112     0380731851                                       Mystic River
# 113     0312983271         Full House (Janet Evanovich's Full Series)
# 114     0446611212                                   Violets Are Blue
# 115     0446605484                  Roses Are Red (Alex Cross Novels)
# ...            ...                                                ...
# 270140  0800758307                                  Postmarked Heaven
# 270141  0801064252                                       Face to Face
# 270142  0801438543  Under the Black Umbrella: Voices from Colonial...
# 270144  0801064562    Just Think: Nourish Your Mind to Feed Your Soul
# 270145  0801064422  The Bumps Are What You Climb on: Encouragement...
#
#                     author                 publisher    year   year_bin  \
# ...

# %% [markdown]
# ## Sorting Book year 1897 to 1925 For USA Reader

# %%
# Segrigating 1897 to 1925 Frome Bookrate
usa_year1925=usa_year[usa_year['year_bin']=='1897_1925']

# segregate with count of zero rating
populer_usa1925=usa_year1925[usa_year1925['counts_no_zero']>=3].sort_values('final_rating',ascending=False).reset_index()
populer_usa1925=populer_usa1925.drop('index',axis=1)
populer_usa1925.head(10)
# Out:
#          ISBN                                              title  \
# 0  0911662251  Kybalion: A Study of the Hermetic Philosophy o...
# 1  0440772095        RAMONA THE PEST (Ramona Quimby (Paperback))
# 2  0684717603                The GREAT GATSBY (Scribner Classic)
# 3  0307021491                                Alice in Wonderland
# 4  0440745454                             HOW TO EAT FRIED WORMS
# 5  0307002101  My Little Golden Book of Cars and Trucks (Litt...
# 6  0307020630                            Animals Merry Christmas
# 7  0380789310                     The Twelve Crimes of Christmas
#
#                     author                           publisher    year  \
# 0          Three Initiates            Yoga Publication Society  1908.0
# 1           BEVERLY CLEARY                            Yearling  1923.0
# 2     F. Scott Fritzgerald              Scribner Paper Fiction  1920.0
# 3              Jane Werner                        Golden Books  1920.0
# ...

# %% [markdown]
# ## Sorting Book year 1926 to 1950 For USA Reader

# %%
# Segrigating 1926 to 1950 Frome Bookrate
usa_year1950=usa_year[usa_year['year_bin']=='1926_1950']

# segregate with count of zero rating
populer_usa1950=usa_year1950[usa_year1950['counts_no_zero']>=3].sort_values('final_rating',ascending=False).reset_index()
populer_usa1950=populer_usa1950.drop('index',axis=1)
populer_usa1950.head(10)
# Out:
#          ISBN                                              title  \
# 0  0060800712                                    True Believer's
# 1  0395071224                                         The Hobbit
# 2  0451623762                                            Odyssey
# 3  0875160476                     Secret Science Behind Miracles
# 4  0060263954             Stuart Little 60th Anniversary Edition
# 5  0717802418                   Manifesto of the Communist Party
# 6  0448095262  Clue of the Leaning Chimney (Nancy Drew (Hardc...
# 7  044809522X  The Clue in the Crumbling Wall (Nancy Drew Mys...
# 8  0684717972                                   Farewell to Arms
# 9  0582530083                               Animal Farm (Bridge)
#
#              author                     publisher    year   year_bin location  \
# 0       Eric Hoffer      HarperCollins Publishers  1942.0  1926_1950      usa
# 1  J. R. R. Tolkien      Houghton Mifflin Company  1938.0  1926_1950      usa
# ...

# %% [markdown]
# ## Sorting Book year 1951 to 1975 For USA Reader

# %%
# Segrigating 1951 to 1975 Frome Bookrate
usa_year1975=usa_year[usa_year['year_bin']=='1951_1975']

# segregate with count of zero rating
populer_usa1975=usa_year1975[usa_year1975['counts_no_zero']>=3].sort_values('final_rating',ascending=False).reset_index()
populer_usa1975=populer_usa1975.drop('index',axis=1)
populer_usa1975.head(10)
# Out:
#          ISBN                                              title  \
# 0  0395082552     The Two Towers (Lord of the Rings (Hardcover))
# 1  0395193958  The Lord of the Rings (Leatherette Collector's...
# 2  0394815009                              The Phantom Tollbooth
# 3  0060648082                             Freedom from the Known
# 4  0671664581                                       Go Ask Alice
# 5  0394810112                  Charlie and the Chocolate Factory
# 6  0060256680  Where the Sidewalk Ends: The Poems and Drawing...
# 7  0226474844   The Savage Mind (Nature of Human Society Series)
# 8  0451519167                                Pride and Prejudice
# 9  039513692X  Western Birds (Peterson Field Guides (Paperback))
#
#                  author                                   publisher    year  \
# 0      J. R. R. Tolkien                    Houghton Mifflin Company  1967.0
# 1      J. R. R. Tolkien                    Houghton Mifflin Company  1974.0
# ...

# %% [markdown]
# ## Sorting Book year 1976 to 2000 For USA Reader

# %%
# Segrigating 1976 to 2000 Frome Bookrate
usa_year2000=usa_year[usa_year['year_bin']=='1976_2000']

# segregate with count of zero rating
populer_usa2000=usa_year2000[usa_year2000['counts_no_zero']>=3].sort_values('final_rating',ascending=False).reset_index()
populer_usa2000=populer_usa2000.drop('index',axis=1)
populer_usa2000.head(10)
# Out:
#          ISBN                                              title  \
# 0  092927959X  Nausicaa of the Valley of Wind (Nausicaa of th...
# 1  067978179X  Three Plays: Blithe Spirit/Hay Fever/Private L...
# 2  0517223651    Gray's Anatomy: The Classic Collector's Edition
# 3  0736410023  The Tigger Movie: A Read-Aloud Storybook (Read...
# 4  0140238026                         The Complete Book of Herbs
# 5  0877797099            Merriam-Webster's Collegiate Dictionary
# 6  0786831901  Cooking with Mickey &amp; Friends : More Than ...
# 7  087701759X                              Mama, Do You Love Me?
# 8  0894808559           Forget-Me-Nots: A Victorian Book of Love
# 9  0316106313  Heart of the Home : Notes From a Vineyard Kitchen
#
#               author              publisher    year   year_bin location  age  \
# 0     Hayao Miyazaki                    Viz  1990.0  1976_2000      usa   48
# 1        Noel Coward      Vintage Books USA  1999.0  1976_2000      usa   46
# ...

# %% [markdown]
# ## Sorting Book year 2001 to 2021 For USA Reader

# %%
# Segrigating 2001 to 2021 Frome Bookrate
usa_year2021=usa_year[usa_year['year_bin']=='2001_2021']

# segregate with count of zero rating
populer_usa2021=usa_year2021[usa_year2021['counts_no_zero']>=3].sort_values('final_rating',ascending=False).reset_index()
populer_usa2021=populer_usa2021.drop('index',axis=1)
populer_usa2021.head(10)
# Out:
#          ISBN                                              title  \
# 0  1577311922  The Seven Whispers: Listening to the Voice of ...
# 1  0964326191                                   The Eye of The I
# 2  1929462379                           Bug, Witch and the Robot
# 3  1561709336  Power vs. Force: The Hidden Determinants of Hu...
# 4  0425186776  Last Man Down: A New York City Fire Chief and ...
# 5  1929462239  Sluggy Freelance: Yippy Skippy, the Evil! (Boo...
# 6  0321130073  HTML for the World Wide Web with XHTML and CSS...
# 7  0618153993     The Two Towers (The Lord of the Rings, Part 2)
# 8  0757300073  Chicken Soup for the Soul of America : Stories...
# 9  0312323131                                 Hide Yourself Away
#
#               author                 publisher    year   year_bin location  \
# 0  Christina Baldwin         New World Library  2002.0  2001_2021      usa
# 1   David R. Hawkins               Veritas Pub  2001.0  2001_2021      usa
# ...

# %%
bookrate
# Out:
#           index  userid        ISBN  \
# 0             0  276925  0971880107
# 1          2502  276925  0316666343
# 2          3797  276925  0385504209
# 3          4680  276925  0804106304
# 4          5199  276925  002542730X
# ...         ...     ...         ...
# 270142  1031127  109339  0801438543
# 270143  1031128  141040  0801491304
# 270144  1031129  263665  0801064562
# 270145  1031130  271450  0801064422
# 270146  1031131   54271  0801063248
#
#                                                     title              author  \
# 0                                             Wild Animus        Rich Shapero
# 1                               The Lovely Bones: A Novel        Alice Sebold
# 2                                       The Da Vinci Code           Dan Brown
# 3                                       The Joy Luck Club             Amy Tan
# 4       Politically Correct Bedtime Stories: Modern Ta...   James Finn Garner
# ...

# %% [markdown]
# ## Sorting Canada's Populer Book On Age Bin

# %%
# Sorting Canada user 
user_can=bookrate[bookrate['location']==' canada']

# Selecting Colunms
can_reader=user_can[['ISBN','title','author','publisher','year','year_bin','location','age','age_bin','counts','counts_no_zero','final_rating']]
can_reader
# Out:
#               ISBN                                              title  \
# 186     0312195516                The Red Tent (Bestselling Backlist)
# 187     0684872153                    Angela's Ashes (MMP) : A Memoir
# 188     0446608955                                 A Walk to Remember
# 189     0804114986                          The Bonesetter's Daughter
# 190     0553279378                    I Know Why the Caged Bird Sings
# ...            ...                                                ...
# 270120  078970210X                         Running a Perfect Web Site
# 270127  0802006671              Corporate Crime: Contemporary Debates
# 270128  0802064698                          A.M. Klein: Short Stories
# 270129  0802085164  Blood on the Hills: The Canadian Army in the K...
# 270146  0801063248  Growing Strong Daughters: Encouraging Girls to...
#
#                     author                    publisher    year   year_bin  \
# ...

# %%
# Count of Age Bin of USA Reader
can_reader['age_bin'].value_counts().to_frame()
# Out:
#              age_bin
# young          14821
# middle_aged     5320
# teen            2003
# adult           1144
# aged              95

# %%
# Count of Year Bin of USA Reader
can_reader['year_bin'].value_counts().to_frame()
# Out:
#            year_bin
# 1976_2000     18722
# 2001_2021      3969
# 1951_1975       647
# 1926_1950        33
# 1897_1925        12

# %% [markdown]
# ## Sorting Canada's Populer Book On Age Bin of Teeneger 10-25

# %%
# Sorting datset for teen Reader
bookrate_can_teen=can_reader[can_reader['age_bin']=='teen']

# segregate with count of zero rating
populer_can_teen=bookrate_can_teen[bookrate_can_teen['counts_no_zero']>=10].sort_values('final_rating',ascending=False).reset_index()
populer_can_teen=populer_can_teen.drop('index',axis=1)
populer_can_teen
# Out:
#          ISBN                                              title  \
# 0  0316107387  Night of the Mary Kay Commandos Featuring Smel...
# 1  1841952753                                          Happiness
# 2  0393320979                   Beowulf: A New Verse Translation
# 3  0330487612                 Bridget Jones' Diary (Film Tie-in)
# 4  0425141551                                         Paper Doll
# 5  0812580346                                       Flashforward
# 6  0446519723                        Where the Heart Is: A Novel
# 7  1551667827                                  Destinys Daughter
# 8  0553567152                                 Don't Die, My Love
#
#                author                  publisher    year   year_bin location  \
# 0      Berke Breathed      Little Brown &amp; Co  1989.0  1976_2000   canada
# 1       Will Ferguson            Canongate Books  2002.0  2001_2021   canada
# 2       Seamus Heaney  W.W. Norton &amp; Company  2001.0  2001_2021   canada
# ...

# %% [markdown]
# ## Sorting Canada's Populer Book On Age Bin of Young 25-40

# %%
# Sorting datset for teen Reader
bookrate_can_young=can_reader[can_reader['age_bin']=='young']

# segregate with count of zero rating
populer_can_young=bookrate_can_young[bookrate_can_young['counts_no_zero']>=10].sort_values('final_rating',ascending=False).reset_index()
populer_can_young=populer_can_young.drop('index',axis=1)
populer_can_young.head(10)
# Out:
#          ISBN                                              title  \
# 0  0836213122  There's Treasure Everywhere--A Calvin and Hobb...
# 1  0446610771                                           Warchild
# 2  1571458735  Uncle John's Ahh-Inspiring Bathroom Reader (Ba...
# 3  2253140872                                  L'Ecume Des Jours
# 4  0066238501                      Complete Chronicles of Narnia
# 5  0836213319                       Dilbert: A Book of Postcards
# 6  0451458370                  Alien Taste (Roc Science Fiction)
# 7  1573226122                                  Lord of the Flies
# 8  0060919884                                   The Writing Life
# 9  0316107417                                       Happy Trails
#
#                       author                     publisher    year   year_bin  \
# 0             Bill Watterson     Andrews McMeel Publishing  1996.0  1976_2000
# 1             Karin Lowachee                        Aspect  2002.0  2001_2021
# ...

# %% [markdown]
# ## Sorting Canada's Populer Book On Age Bin of Middel Aged 40-55

# %%
# Sorting datset for teen Reader
bookrate_can_maged=can_reader[can_reader['age_bin']=='middle_aged']

# segregate with count of zero rating
populer_can_maged=bookrate_can_maged[bookrate_can_maged['counts_no_zero']>=10].sort_values('final_rating',ascending=False).reset_index()
populer_can_maged=populer_can_maged.drop('index',axis=1)
populer_can_maged.head(10)
# Out:
#          ISBN                                              title  \
# 0  055329024X                                              Earth
# 1  0060007192     Lemony Snicket: The Unauthorized Autobiography
# 2  0394740181  American Indian Myths and Legends (Pantheon Fa...
# 3  0515135216                                      Dark Symphony
# 4  0140264795                                     Rosie: A Novel
# 5  0688084885                               Memories of Midnight
# 6  0553275704                                     The Sisterhood
# 7  0425177351  Bio-Strike (Tom Clancy's Power Plays (Paperback))
# 8  0821760262              Wild Winds (Zebra Historical Romance)
# 9  1557732647                                   Unnatural Causes
#
#              author                 publisher    year   year_bin location  \
# 0        David Brin             Spectra Books  1991.0  1976_2000   canada
# 1    Lemony Snicket             HarperCollins  2002.0  2001_2021   canada
# ...

# %% [markdown]
# ## Sorting Canada's Populer Book On Age Bin of Adult 56-70

# %%
# Sorting datset for teen Reader
bookrate_can_adult=can_reader[can_reader['age_bin']=='adult']

# segregate with count of zero rating
populer_can_adult=bookrate_can_adult[bookrate_can_adult['counts_no_zero']>=10].sort_values('final_rating',ascending=False).reset_index()
populer_can_adult=populer_can_adult.drop('index',axis=1)
populer_can_adult.head(10)
# Out:
#          ISBN                                              title  \
# 0  2070408507                                    Le Petit Prince
# 1  0684196395         ONE FOR THE MONEY : A Stephanie Plum Novel
# 2  0670813648                                             Misery
# 3  039575514X                                         My Antonia
# 4  0671442686              Restaurant at the End of the Universe
# 5  0440940605              I Am the Cheese (Laurel-Leaf Library)
# 6  0316735736                        All He Ever Wanted: A Novel
# 7  0380726297                                             Sacred
# 8  0553269216  Rainbow Valley (Anne of Green Gables Novels (P...
# 9  0451524667                                        Animal Farm
#
#                       author                  publisher    year   year_bin  \
# 0  Antoine de Saint-ExupÃ©ry                  Gallimard  1999.0  1976_2000
# 1            Janet Evanovich                   Scribner  1994.0  1976_2000
# ...

# %% [markdown]
# ## Sorting Canada's Populer Book On Age Bin of Aged 71-85

# %%
# Sorting datset for teen Reader
bookrate_can_aged=can_reader[can_reader['age_bin']=='aged']

# segregate with count of zero rating
populer_can_aged=bookrate_can_aged[bookrate_can_aged['counts_no_zero']>=3].sort_values('final_rating',ascending=False).reset_index()
populer_can_aged=populer_can_aged.drop('index',axis=1)
populer_can_aged.head(10)
# Out:
#          ISBN                        title         author  \
# 0  0312853807                  Zero Coupon    Paul Erdman
# 1  0345438221             Lines of Defense   Barry Siegel
# 2  0671419773                    Democracy    Joan Didion
# 3  0374150036  The Evening Wolves: A Novel     Joan Chase
# 4  0394407571  A Flag for Sunrise: A Novel   Robert Stone
# 5  0786701420               Eating Pavlova   D. M. Thomas
# 6  0385237081             The Evening News  Arthur Hailey
# 7  0671692976                     BIG HYPE   Avery Corman
#
#                     publisher    year   year_bin location  age age_bin  \
# 0               St Martins Pr  1993.0  1976_2000   canada   72    aged
# 1            Ballantine Books  2003.0  2001_2021   canada   71    aged
# 2               Bookthrift Co  1984.0  1976_2000   canada   79    aged
# 3  Farrar Straus &amp; Giroux  1989.0  1976_2000   canada   79    aged
# 4            Random House Inc  1981.0  1976_2000   canada   79    aged
# ...

# %% [markdown]
# ## Sorting Canada's Populer Book On Year Bin

# %%
# Sorting Canada user 
user_can=bookrate[bookrate['location']==' canada']

# Selecting Colunms
can_reader=user_can[['ISBN','title','author','publisher','year','year_bin','location','age','age_bin','counts','counts_no_zero','final_rating']]
can_reader
# Out:
#               ISBN                                              title  \
# 186     0312195516                The Red Tent (Bestselling Backlist)
# 187     0684872153                    Angela's Ashes (MMP) : A Memoir
# 188     0446608955                                 A Walk to Remember
# 189     0804114986                          The Bonesetter's Daughter
# 190     0553279378                    I Know Why the Caged Bird Sings
# ...            ...                                                ...
# 270120  078970210X                         Running a Perfect Web Site
# 270127  0802006671              Corporate Crime: Contemporary Debates
# 270128  0802064698                          A.M. Klein: Short Stories
# 270129  0802085164  Blood on the Hills: The Canadian Army in the K...
# 270146  0801063248  Growing Strong Daughters: Encouraging Girls to...
#
#                     author                    publisher    year   year_bin  \
# ...

# %% [markdown]
# ## Sorting Canada's Populer Book On Year Bin 1897-1925

# %%
# Segrigating 1897 to 1925 Frome Bookrate
can_year1925=can_reader[can_reader['year_bin']=='1897_1925']

# segregate with count of zero rating
populer_can1925=can_year1925[can_year1925['counts_no_zero']>=2].sort_values('final_rating',ascending=False).reset_index()
populer_can1925=populer_can1925.drop('index',axis=1)
populer_can1925.head(10)
# Out:
#          ISBN                                              title  \
# 0  0440772435  RAMONA AND HER MOTHER (Ramona Quimby (Paperback))
#
#            author publisher    year   year_bin location  age age_bin  counts  \
# 0  BEVERLY CLEARY  Yearling  1923.0  1897_1925   canada   38   young       6
#
#    counts_no_zero  final_rating
# 0               2           5.0

# %% [markdown]
# ## Sorting Canada's Populer Book On Year Bin 1926-1950

# %%
# Segrigating 1926 to 1950 Frome Bookrate
can_year1950=can_reader[can_reader['year_bin']=='1926_1950']

# segregate with count of zero rating
populer_can1950=can_year1950[can_year1950['counts_no_zero']>=2].sort_values('final_rating',ascending=False).reset_index()
populer_can1950=populer_can1950.drop('index',axis=1)
populer_can1950.head(10)
# Out:
#          ISBN                                              title  \
# 0  0152465030                                  The Little Prince
# 1  0885660838  Bonheur d Occasion (QuÃ©bec 10/10 [i.e. dix su...
# 2  0448095203  The Clue in the Jewel Box (Nancy Drew Mystery ...
# 3  0802812201                                  Descent into Hell
# 4  0448089092  Great Airport Mystery (Hardy Boys Mystery Stor...
# 5  0721408281            Wizard of Oz (Well Loved Tales Level 3)
#
#                      author                           publisher    year  \
# 0  Antoine De Saint-Exupery                            Harcourt  1943.0
# 1             Gabrielle Roy                                 Adp  1947.0
# 2             Carolyn Keene                Grosset &amp; Dunlap  1943.0
# 3          Charles Williams  Wm. B. Eerdmans Publishing Company  1937.0
# 4         Franklin W. Dixon                Grosset &amp; Dunlap  1930.0
# 5             L. Frank Baum                       Penguin U S A  1940.0
#
# ...

# %% [markdown]
# ## Sorting Canada's Populer Book On Year Bin 1951-1975

# %%
# Segrigating 1951 to 1975 Frome Bookrate
can_year1975=can_reader[can_reader['year_bin']=='1951_1975']

# segregate with count of zero rating
populer_can1975=can_year1975[can_year1975['counts_no_zero']>=5].sort_values('final_rating',ascending=False).reset_index()
populer_can1975=populer_can1975.drop('index',axis=1)
populer_can1975.head(10)
# Out:
#          ISBN                                              title  \
# 0  0048230871                             The Lord of the rings,
# 1  0394730380                                 The Zen of Running
# 2  0060264306       Little House in the Big Woods (Little House)
# 3  0448095114  The Clue of the Broken Locket (Nancy Drew Myst...
# 4  0380014033                                      Lord of Light
# 5  014044100X  The Epic of Gilgamesh: An English Version With...
# 6  0385092881  The Waning of the Middle Ages: A Study of the ...
# 7  0448095491  The Secret of Mirror Bay (Nancy Drew Mystery S...
# 8  0440178592                                 The Sensuous Woman
#
#                  author               publisher    year   year_bin location  \
# 0       J. R. R Tolkien         Allen and Unwin  1968.0  1951_1975   canada
# 1             Fred Rohe        Random House Inc  1975.0  1951_1975   canada
# 2  Laura Ingalls Wilder           HarperCollins  1953.0  1951_1975   canada
# ...

# %% [markdown]
# ## Sorting Canada's Populer Book On Year Bin 1976-2000

# %%
# Segrigating 1926 to 1950 Frome Bookrate
can_year2000=can_reader[can_reader['year_bin']=='1976_2000']

# segregate with count of zero rating
populer_can2000=can_year2000[can_year2000['counts_no_zero']>=5].sort_values('final_rating',ascending=False).reset_index()
populer_can2000=populer_can2000.drop('index',axis=1)
populer_can2000.head(10)
# Out:
#          ISBN                                              title  \
# 0  0684842319  Our Bodies Ourselves For The New Century (A To...
# 1  0452279615  The Drawing of the Three (The Dark Tower, Book 2)
# 2  0451525817                                  The Secret Garden
# 3  0451933028        The Green Mile: The Complete Six Part Novel
# 4  0807068195                             New and Selected Poems
# 5  0836213122  There's Treasure Everywhere--A Calvin and Hobb...
# 6  0394548108                             STRY SHIPWRCKED SAILOR
# 7  0316108677  His Kisses Are Dreamy...but Those Hairballs Do...
# 8  2707301485                                 En Attendant Godot
# 9  0452279623           The Waste Lands (The Dark Tower, Book 3)
#
#                                   author                  publisher    year  \
# 0  Boston Women's Health Book Collective                 Touchstone  1998.0
# 1                           Stephen King                Plume Books  1997.0
# ...

# %% [markdown]
# ## Sorting Canada's Populer Book On Year Bin 2001-2021

# %%
# Segrigating 2001 to 2021 Frome Bookrate
can_year2021=can_reader[can_reader['year_bin']=='2001_2021']

# segregate with count of zero rating
populer_can2021=can_year2021[can_year2021['counts_no_zero']>=5].sort_values('final_rating',ascending=False).reset_index()
populer_can2021=populer_can2021.drop('index',axis=1)
populer_can2021.head(10)
# Out:
#          ISBN                                              title  \
# 0  0973047305                                              Slide
# 1  0060278250                    Abhorsen (The Abhorsen Trilogy)
# 2  0743250346  The Frumious Bandersnatch:  A Novel of the 87t...
# 3  060961097X                          The Clan of the Cave Bear
# 4  0446610771                                           Warchild
# 5  0060506512                                     The Fifth Ring
# 6  0385492707                          A Love of My Own: A Novel
# 7  1571458735  Uncle John's Ahh-Inspiring Bathroom Reader (Ba...
# 8  0971942315                             The Greatest Discovery
# 9  0520227352            Always Coming Home (California Fiction)
#
#                       author                       publisher    year  \
# 0                   Matteson   Hushion House Publishing Ltd.  2002.0
# 1                  Garth Nix                             Eos  2003.0
# ...

# %%
#bins = [0,1925, 1950,1975, 2001,2021, np.inf]
#labels = ["'1897_1925'","'1926_1950'","'1951_1975'","'1976_2000'","'2001_2021'"]
#bookrate['year-bin'] = pd.cut(bookrate['year'], bins=bins, labels=labels)

# %%
#col = 'year'
#conditions = [
#              bookrate[col].between(1897,1925),   # inclusive = True is the default
#              bookrate[col].between(1926,1950),  
#              bookrate[col].between(1951,1975),
#              bookrate[col].between(1976,2000),
#              df[col].ge(2000)
#             ]
#choices = ["'1897_1925'","'1926_1950'","'1951_1975'","'1976_2000'","'2001_2021'"]

#bookrate["year_bin"] = np.select(conditions, choices, default=np.nan)
